# %%
import numpy as np
import polars as pl

# %%
def get_lf(path: str):
    return pl.scan_csv(path, separator=";")


entities = get_lf("data/data_for_spb_hakaton_entities1-Table 1.csv").filter(pl.col("entity_id").is_not_null()).select(
    "entity_id", "area", "type", "status", "priority", "ticket_number", "name", "estimation").collect()

ticket2id = dict(zip(entities["ticket_number"].to_list(), entities["entity_id"].to_list()))

entities = entities.select("entity_id", "area", "type", "status", "priority", "name", "estimation").with_columns(
    pl.col('status').replace_strict(
        ['Создано', 'Закрыто', 'Выполнено', 'Отклонен исполнителем'],
        [0, 2, 2, 2], default=1, return_dtype=pl.Int8)).with_columns(
    pl.col('type').replace_strict(
        ['Дефект'],
        [1], default=0, return_dtype=pl.Int8)
).with_columns(pl.col("estimation").fill_null(0)).with_columns(pl.lit(0).alias("status"))
entities
# Out:
# shape: (2_485, 7)
# ┌───────────┬─────────────────────┬──────┬────────┬─────────────┬─────────────────────┬────────────┐
# │ entity_id ┆ area                ┆ type ┆ status ┆ priority    ┆ name                ┆ estimation │
# │ ---       ┆ ---                 ┆ ---  ┆ ---    ┆ ---         ┆ ---                 ┆ ---        │
# │ i64       ┆ str                 ┆ i8   ┆ i32    ┆ str         ┆ str                 ┆ i64        │
# ╞═══════════╪═════════════════════╪══════╪════════╪═════════════╪═════════════════════╪════════════╡
# │ 94297     ┆ Система.Таск-трекер ┆ 1    ┆ 0      ┆ Средний     ┆ [FE] Бэклог.        ┆ 60         │
# │           ┆                     ┆      ┆        ┆             ┆ Кастомизация коло…  ┆            │
# │ 102481    ┆ Система.Ошибки      ┆ 0    ┆ 0      ┆ Критический ┆ [ГенераторДокументо ┆ 432000     │
# │           ┆                     ┆      ┆        ┆             ┆ в] Интеграц…        ┆            │
# │ 1805925   ┆ Система.Таск-трекер ┆ 1    ┆ 0      ┆ Высокий     ┆ [FE] История        ┆ 60         │
# │           ┆                     ┆      ┆        ┆             ┆ изменений. Пустые…  ┆            │
# │ 1934905   ┆ Система.Таск-трекер ┆ 1    ┆ 0      ┆ Средний     ┆ [FE] Зависимые      ┆ 0          │
# │           ┆                     ┆      ┆        ┆             ┆ поля. Тип реакц…    ┆            │
# │ 1943849   ┆ Система.Ошибки      ┆ 1    ┆ 0      ┆ Низкий      ┆ [BE] При сортировке ┆ 0          │
# │           ┆                     ┆      ┆        ┆             ┆ по Теме ес…         ┆            │
# │ …         ┆ …                   ┆ …    ┆ …      ┆ …           ┆ …                   ┆ …          │
# │ 5179477   ┆ Управление релизами ┆ 0    ┆ 0      ┆ Средний     ┆ [PPPL] [FE] -       ┆ 57600      │
# │           ┆ изменениям…         ┆      ┆        ┆             ┆ Исследовать ui-k…   ┆            │
# │ 5179714   ┆ Управление релизами ┆ 0    ┆ 0      ┆ Средний     ┆ [PPPL] [FE] -       ┆ 86400      │
# │           ┆ изменениям…         ┆      ┆        ┆             ┆ Написать базовую…   ┆            │
# │ 5179793   ┆ Управление релизами ┆ 0    ┆ 0      ┆ Средний     ┆ [PPPL] [FE] -       ┆ 28800      │
# │           ┆ изменениям…         ┆      ┆        ┆             ┆ Сделать  роутинг…   ┆            │
# │ 5179847   ┆ Управление релизами ┆ 0    ┆ 0      ┆ Средний     ┆ [PPPL] [FE] -       ┆ 28800      │
# │           ┆ изменениям…         ┆      ┆        ┆             ┆ Написать парсинг…   ┆            │
# │ 5179881   ┆ Управление релизами ┆ 0    ┆ 0      ┆ Средний     ┆ [PPPL] [FE] -       ┆ 57600      │
# │           ┆ изменениям…         ┆      ┆        ┆             ┆ Сделать автозапо…   ┆            │
# └───────────┴─────────────────────┴──────┴────────┴─────────────┴─────────────────────┴────────────┘

# %%
import numpy as np

# %%
np.array([1,2,3]).tolist()
# Out:
# [1, 2, 3]

# %%
sprints = get_lf("data/sprints-Table 1.csv").filter(pl.col("sprint_name").is_not_null()).select(
    "sprint_name", "sprint_start_date", "entity_ids").with_columns(
    pl.col("sprint_start_date").str.to_datetime().dt.timestamp("ms") // 86400000).collect()

tasks = sprints.with_columns(pl.col("entity_ids").str.strip_chars(r'{}').str.split(",").alias("entity_id"))
t = tasks.with_columns(pl.col("entity_id").list.len())
         
tasks = tasks.explode("entity_id").with_columns(pl.col("entity_id").cast(pl.Int64, strict=False))
all_tasks_estimations = entities.select("entity_id", "estimation").join(tasks.select("entity_id", "sprint_name"), on="entity_id").group_by("sprint_name").agg(pl.col("estimation").sum())


sprints = {k: (i, v) for i, (k, v) in
           enumerate(zip(sprints["sprint_name"].to_list(), sprints["sprint_start_date"].to_list()))}

from enum import IntEnum


class Feature(IntEnum):
    to_do_estimation = 0
    processed_estimation = 1
    done_estimation = 2
    removed_estimation = 3
    blocked_tasks_estimation = 4
    created_tasks_estimation = 5
    excluded_tasks_estimation = 6
    created_tasks_amount = 7
    excluded_tasks_amount = 8


day_features = np.zeros((len(sprints), 14, len(Feature._member_names_)))

# %%
all_tasks_estimations
# Out:
# shape: (6, 2)
# ┌─────────────────────────────────┬────────────┐
# │ sprint_name                     ┆ estimation │
# │ ---                             ┆ ---        │
# │ str                             ┆ i64        │
# ╞═════════════════════════════════╪════════════╡
# │ Спринт 2024.3.5.NPP Shared Spr… ┆ 17784060   │
# │ Спринт 2024.3.3.NPP Shared Spr… ┆ 17776920   │
# │ Спринт 2024.3.4.NPP Shared Spr… ┆ 15811200   │
# │ Спринт 2024.3.1.NPP Shared Spr… ┆ 18338580   │
# │ Спринт 2024.3.2.NPP Shared Spr… ┆ 17067720   │
# │ Спринт 2024.3.6.NPP Shared Spr… ┆ 20214060   │
# └─────────────────────────────────┴────────────┘

# %%
t
# Out:
# shape: (6, 4)
# ┌────────────────────────────┬───────────────────┬─────────────────────────────────┬───────────┐
# │ sprint_name                ┆ sprint_start_date ┆ entity_ids                      ┆ entity_id │
# │ ---                        ┆ ---               ┆ ---                             ┆ ---       │
# │ str                        ┆ i64               ┆ str                             ┆ u32       │
# ╞════════════════════════════╪═══════════════════╪═════════════════════════════════╪═══════════╡
# │ Спринт 2024.3.1.NPP Shared ┆ 19907             ┆ {4449728,4450628,4451563,44519… ┆ 464       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# │ Спринт 2024.3.2.NPP Shared ┆ 19921             ┆ {4506286,4429413,4327418,43700… ┆ 437       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# │ Спринт 2024.3.3.NPP Shared ┆ 19935             ┆ {4646403,4176602,4555571,44974… ┆ 501       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# │ Спринт 2024.3.4.NPP Shared ┆ 19949             ┆ {4805777,4596004,4594168,45237… ┆ 375       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# │ Спринт 2024.3.5.NPP Shared ┆ 19963             ┆ {4861060,4856927,4868451,40926… ┆ 540       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# │ Спринт 2024.3.6.NPP Shared ┆ 19977             ┆ {5034080,5052223,4620977,51371… ┆ 513       │
# │ Spr…                       ┆                   ┆                                 ┆           │
# └────────────────────────────┴───────────────────┴─────────────────────────────────┴───────────┘

# %%
all_tasks_estimations
# Out:
# shape: (6, 2)
# ┌─────────────────────────────────┬────────────┐
# │ sprint_name                     ┆ estimation │
# │ ---                             ┆ ---        │
# │ str                             ┆ i64        │
# ╞═════════════════════════════════╪════════════╡
# │ Спринт 2024.3.5.NPP Shared Spr… ┆ 17784060   │
# │ Спринт 2024.3.3.NPP Shared Spr… ┆ 17776920   │
# │ Спринт 2024.3.4.NPP Shared Spr… ┆ 15811200   │
# │ Спринт 2024.3.1.NPP Shared Spr… ┆ 18338580   │
# │ Спринт 2024.3.2.NPP Shared Spr… ┆ 17067720   │
# │ Спринт 2024.3.6.NPP Shared Spr… ┆ 20214060   │
# └─────────────────────────────────┴────────────┘

# %%
# entities
state2int = {"created": 0, "closed": 2, "done": 2, "rejectedByThePerformer": 2}
entities = {k: list(v[0]) + ["", "", 0] for k, v in entities.rows_by_key("entity_id").items()}

# %%
sprints["Спринт 2024.3.1.NPP Shared Sprint"]
# Out:
# (0, 19907)

# %%
entities[4533564]
# Out:
# ['Система.Таск-трекер',
#  0,
#  2,
#  'Средний',
#  '[BE] Добавление типов полей в таблицы - Поддержка экспорта',
#  0,
#  '',
#  '',
#  0]

# %%
entities
# Out:
# {94297: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Бэклог. Кастомизация колонок. Кастомизация для панелей "спринты" и  "бэклоги" зависима друг от друга',
#   60,
#   '',
#   '',
#   0],
#  102481: ['Система.Ошибки',
#   0,
#   2,
#   'Критический',
#   '[ГенераторДокументов] Интеграция со Система.ГенераторДокументов в части синхронизации Стандартных решений',
#   432000,
#   '',
#   '',
#   0],
#  1805925: ['Система.Таск-трекер',
#   1,
#   1,
#   'Высокий',
#   '[FE] История изменений. Пустые строки в истории изменений, если выбрать значение, которое уже было выбрано до редактирования поля',
#   60,
#   '',
#   '',
#   0],
#  1934905: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Зависимые поля. Тип реакции disable НЕ работает для некоторых типов полей',
#   0,
#   '',
#   '',
#   0],
#  1943849: ['Система.Ошибки',
#   1,
#   2,
#   'Низкий',
#   '[BE] При сортировке по Теме если знаки препинания стоят перед буквенными значениями сортировка отрабатывает неправильно',
#   0,
#   '',
#   '',
#   0],
#  1966759: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC][PREPROD] При незаполненном обязательном поле Изменяемые ИС текст под полем некорректный',
#   0,
#   '',
#   '',
#   0],
#  2353124: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Паспорт стрима (печатная форма)',
#   3600,
#   '',
#   '',
#   0],
#  2383243: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Настройка dev стенда в Компания',
#   3600,
#   '',
#   '',
#   0],
#  2441405: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC][ST] ЗНУ. При попытке создать ЗНУ пользователем без прав появляется и исчезает шторка создания ЗНУ. ',
#   0,
#   '',
#   '',
#   0],
#  2444222: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-Док][FE][Публикация] Левое меню публикации',
#   0,
#   '',
#   '',
#   0],
#  2503655: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[BE] Синхронизация стандартных решений из Система.ГенераторДокументов',
#   0,
#   '',
#   '',
#   0],
#  2536878: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[Дефект] [FE] Теги. При тегировании несуществующего пользователя нет текста "Нет совпадений"',
#   28800,
#   '',
#   '',
#   0],
#  2540151: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт документа формата DOCX',
#   0,
#   '',
#   '',
#   0],
#  2582366: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] [PREPROD](fixed 1.28.0) Бэклог. Не работает ввод пробела при поиске спринтов в панели спринтов',
#   0,
#   '',
#   '',
#   0],
#  2623949: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API (error responses)',
#   28800,
#   '',
#   '',
#   0],
#  2824925: ['Система.Ошибки',
#   0,
#   2,
#   'Высокий',
#   '[ML Инц-2] Группировка инцидентов с помощью ML-модели',
#   144000,
#   '',
#   '',
#   0],
#  2840563: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Таск трекер. Задублированные запросы personal-settings с фронта на представлениях Таск трекер и Бэклог',
#   0,
#   '',
#   '',
#   0],
#  2867204: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] API v1 Получение полной сущности со смаппленными кодами на универсальную модель справочника ',
#   57600,
#   '',
#   '',
#   0],
#  2887761: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[СДок][BE][Иерархия заголовков] Разный шрифт для заголовков',
#   7200,
#   '',
#   '',
#   0],
#  2938657: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] История изменений. Метки и компоненты. Некорректно отображение состава и статуса изменений меток и компонентов в истории изменений',
#   0,
#   '',
#   '',
#   0],
#  2970791: ['Система.Таск-трекер',
#   1,
#   1,
#   'Низкий',
#   '[FE] Структура. Нельзя закрыть выпадающие списки в окне создания и редактирования структуры кликом на шеврон для раскрытия/ закрытия списка',
#   0,
#   '',
#   '',
#   0],
#  2980909: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   ' [QA] Интеграция Система.Конфигурации',
#   144000,
#   '',
#   '',
#   0],
#  2995479: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-док][FE][Анкета]  "Представление модели части объекта" - расширение файла',
#   14400,
#   '',
#   '',
#   0],
#  3027722: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Конструктор фильтров. Функция me() подставляется в некорректное место в запросе , если она была выбрана внутри дропдауна',
#   0,
#   '',
#   '',
#   0],
#  3051159: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[AQA] Обновить в тестовых сущностях поля, связанные с релизами',
#   28800,
#   '',
#   '',
#   0],
#  3057885: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[FE] Группировка инцидентов с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3127873: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1  entity-types. Некорректный текст сообщения при обновлении не обновляемого атрибута типа сущности',
#   0,
#   '',
#   '',
#   0],
#  3130955: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание плагина для юридических документов',
#   3600,
#   '',
#   '',
#   0],
#  3185895: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Скролл в таблице',
#   57600,
#   '',
#   '',
#   0],
#  3206897: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE][Техдолг] Проработать механизм работы с моками',
#   57600,
#   '',
#   '',
#   0],
#  3207618: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Макрос Код iframe',
#   60,
#   '',
#   '',
#   0],
#  3207737: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Структура. Фронт не запрашивает порцию задач с page=0 после добавления/ удаления колонки на экране',
#   0,
#   '',
#   '',
#   0],
#  3315188: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE]Структура. Не обновляется updateDate после изменения структуры.',
#   14400,
#   '',
#   '',
#   0],
#  3332524: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[BE] Инвистигация АПИ ОПС для виджета NPS',
#   28800,
#   '',
#   '',
#   0],
#  3335475: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Добавление макроса, редактирование, шторка',
#   28800,
#   '',
#   '',
#   0],
#  3335507: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Ресайз (рамка + абсолютное значение)',
#   14400,
#   '',
#   '',
#   0],
#  3335563: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Запрет на взаимодействие с другими макросами',
#   28800,
#   '',
#   '',
#   0],
#  3335577: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Запрет на копирование макроса',
#   14400,
#   '',
#   '',
#   0],
#  3335613: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] [Макрос Код iframe] Тест кейсы ',
#   144000,
#   '',
#   '',
#   0],
#  3385299: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Карточка Таск трекер. Статус код 500 при загрузке вложений',
#   0,
#   '',
#   '',
#   0],
#  3421421: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  3 типа списка в сравнениях текстового фрагмента + экран сравнения публикаций',
#   0,
#   '',
#   '',
#   0],
#  3424881: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт многоуровневых списков в текстовый фрагмент',
#   3600,
#   '',
#   '',
#   0],
#  3481977: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. Создание структуры без привязки к пространству.',
#   0,
#   '',
#   '',
#   0],
#  3482014: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. Создание структуры к несуществующему пространству.',
#   0,
#   '',
#   '',
#   0],
#  3493071: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '  [Дефект] [FE]  Не работает инлайн -комментарий  в заголовке макроса "Акцентированный блок"',
#   28800,
#   '',
#   '',
#   0],
#  3502800: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Низкий',
#   '[С-док][Создание документа] При выходе из просмотра документа, в теле документа отображаются спец. символы',
#   0,
#   '',
#   '',
#   0],
#  3508978: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Структура. Приложение зависает, если добавить/ удалить колонку в структуре и в этой структуре под её настройки попало менее 51-й Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  3516665: ['Система.Таск-трекер',
#   1,
#   1,
#   'Высокий',
#   '[BE] Не обновляются данные пользователя в entities.properties если данные пользовтаеля изменились в users (в AD)',
#   0,
#   '',
#   '',
#   0],
#  3533870: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Фильтрация. Не работает поиск пользователей в поле Исполнитель',
#   0,
#   '',
#   '',
#   0],
#  3549113: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC 2.0] [ST][PREPROD] Таблица. В табличном отображении по умолчанию отображаются все колонки.',
#   0,
#   '',
#   '',
#   0],
#  3549401: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Настройка обязательности атрибутов шаблона',
#   0,
#   '',
#   '',
#   0],
#  3588880: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE][Техдолг]  Удалить старый код по черновику',
#   14400,
#   '',
#   '',
#   0],
#  3604826: ['Система. Движок',
#   1,
#   1,
#   'Средний',
#   '[BE] GET  v1/entitites/{entityNum}/attributes/relations/{id} с несуществующей сущностью в entityNum возвращает 200',
#   0,
#   '',
#   '',
#   0],
#  3620274: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD]МП. Веха "Провести ИФТ" скорректировать уведомление ',
#   0,
#   '',
#   '',
#   0],
#  3625924: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[С-док][FE][Цветная Валидация]При сохрании раздела с файлом без подписи нет цветной валидации',
#   57600,
#   '',
#   '',
#   0],
#  3626050: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-док][FE][Цветная Валидация]Поля с файлами и подписью не подсвечиваются при разных названиях ',
#   0,
#   '',
#   '',
#   0],
#  3641264: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] Модуль процессов. Отсутствует информация в тосте о количестве задач, не прошедших проверку ',
#   0,
#   '',
#   '',
#   0],
#  3641304: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] Модуль процессов. В тосте о количестве задач, не прошедших проверку лишний текст ',
#   0,
#   '',
#   '',
#   0],
#  3671384: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC][PREPROD] МП. При отсутствии значения атрибута Использует ДК по ИС всплывает сообщение с нечитаемой ошибкой ',
#   0,
#   '',
#   '',
#   0],
#  3675079: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] МП. Отсутствует тост об успешном выполнении запроса после получения ответа от МП',
#   0,
#   '',
#   '',
#   0],
#  3681164: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] История изменений. Отображается пустая история изменений удалении файла, который имеет то же имя и расширение, как и ранее удаленный',
#   0,
#   '',
#   '',
#   0],
#  3681209: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] История изменений. Отображается некорректная история изменений при удалении ВСЕХ вложений',
#   0,
#   '',
#   '',
#   0],
#  3689670: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] APIv1. Тестирование + тест дизайн. Получение /v1/sprints',
#   57600,
#   '',
#   '',
#   0],
#  3701003: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Один и тот же статус можно использовать в разных колонках',
#   0,
#   '',
#   '',
#   0],
#  3723915: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Экспорт многоуровневых списков в табличных фрагментах',
#   3600,
#   '',
#   '',
#   0],
#  3724161: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт многоуровневых списков в табличный фрагмент',
#   3600,
#   '',
#   '',
#   0],
#  3725698: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Таблицы. Копирование строк/столбцов',
#   950400,
#   '',
#   '',
#   0],
#  3749735: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Низкий',
#   '[С-док][FE][Анкета] Скролл к разделу не происходит ',
#   0,
#   '',
#   '',
#   0],
#  3757374: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Общее: трассировка запрсоов (X-Request-Id)',
#   28800,
#   '',
#   '',
#   0],
#  3781039: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[ПЗ][US] Переезд в контур Компания',
#   3600,
#   '',
#   '',
#   0],
#  3791006: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. GET/ fields. В ответе приходит по 2 поля spent, estimation, remainder',
#   0,
#   '',
#   '',
#   0],
#  3796983: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] Макрос: Календарь',
#   115200,
#   '',
#   '',
#   0],
#  3797131: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Учёт рабочего времени. История изменений по модулю учёта рабочего времени',
#   57600,
#   '',
#   '',
#   0],
#  3798425: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[FE] [Управления сущностями] Не обрабатывается ошибка когда данные с бэка не подгружаются',
#   0,
#   '',
#   '',
#   0],
#  3799650: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[AQA] Техдолг по макросу Акцентированный блок',
#   28800,
#   '',
#   '',
#   0],
#  3803163: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[AQA] Автоматизация тест-кейсов по Структуре (FE)',
#   86400,
#   '',
#   '',
#   0],
#  3815067: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   "[AQA] Автоматизация общих тест-кейсов для представления 'Доски'.",
#   86400,
#   '',
#   '',
#   0],
#  3815680: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC][PREPROD] МП. При повторном действии по МП во время его выполнения всплывает неинформативное сообщение с ошибкой',
#   0,
#   '',
#   '',
#   0],
#  3818307: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[С-док][FE]При скачивании файла/подписи файла на кнопках крутится лоадер',
#   0,
#   '',
#   '',
#   0],
#  3818753: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Виджет Недавние действия. Тести рование и тест кейсы',
#   144000,
#   '',
#   '',
#   0],
#  3823975: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность редактирования/сохранения полей в анкете шаблона (число, текст, дата, деньги) ',
#   3600,
#   '',
#   '',
#   0],
#  3824296: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Возможность создания и редактирования полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3825345: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Тест дизайн + тестирование (BE) - Создание дочерней и связанной Таск трекер из родительской',
#   28800,
#   '',
#   '',
#   0],
#  3826504: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Копирование и вставка группы с включенными детьми',
#   0,
#   '',
#   '',
#   0],
#  3828992: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Поиск страниц - POST /pages/get-by-id',
#   28800,
#   '',
#   '',
#   0],
#  3829019: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Копирование строк/столбцов, корнер кейсы',
#   86400,
#   '',
#   '',
#   0],
#  3829030: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Копирование строк/столбцов через hotkeys',
#   28800,
#   '',
#   '',
#   0],
#  3829039: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Вставка скопированных строк/столбцов вне таблицы',
#   57600,
#   '',
#   '',
#   0],
#  3829052: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API.  Получение списка пространств',
#   28800,
#   '',
#   '',
#   0],
#  3829067: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Копирование строк/столбцов. Тестирование часть 1',
#   86400,
#   '',
#   '',
#   0],
#  3829076: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Копирование строк/столбцов. Тест-кейсы. ч2',
#   144000,
#   '',
#   '',
#   0],
#  3830127: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   57600,
#   '',
#   '',
#   0],
#  3830128: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Возможность создания полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3836390: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Возможность создания полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3836437: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания и редактирования полей в анкете шаблона (справочник (одиночный и множественный выбор))',
#   3600,
#   '',
#   '',
#   0],
#  3837909: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Перемещение фрагментов',
#   0,
#   '',
#   '',
#   0],
#  3841940: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Возможность создания и редактирования полей в анкете шаблона (выбор варианта) ',
#   14400,
#   '',
#   '',
#   0],
#  3842914: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Управление доступом к страницам',
#   28800,
#   '',
#   '',
#   0],
#  3847317: ['Система.Вики',
#   0,
#   2,
#   'Низкий',
#   '[UX] Редактор 2.0: Компонент рамки макросов',
#   57600,
#   '',
#   '',
#   0],
#  3864586: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[SA] Привязка инцидентов к проблеме с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3864762: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[QA] Привязка инцидентов к проблеме с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3890401: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка инпута названия (просмотр)',
#   14400,
#   '',
#   '',
#   0],
#  3890402: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка инпута названия (редактирование)',
#   28800,
#   '',
#   '',
#   0],
#  3902314: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Back module для коммуникации FW->FW',
#   57600,
#   '',
#   '',
#   0],
#  3907488: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Сделать Emitter для Eventual Consistency проекций FW ',
#   288000,
#   '',
#   '',
#   0],
#  3907493: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] Сделать Consumer для Eventual Consistency проекций FW',
#   115200,
#   '',
#   '',
#   0],
#  3910233: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Карточка Таск трекер. Учет рабочего времени. Нет тоста для Участника пространства (кот.имеет глобальную роль) при попытке списаться в даты закрытого спринта',
#   57600,
#   '',
#   '',
#   0],
#  3910459: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона (кнопка, выбор варианта)',
#   86400,
#   '',
#   '',
#   0],
#  3910470: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Заливка ячеек цветом. Импорт',
#   0,
#   '',
#   '',
#   0],
#  3910535: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Дополнительные атрибуты публикации для статей стандартных решений',
#   0,
#   '',
#   '',
#   0],
#  3913376: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[С-док][FE][Анкета]В превью отображаются лишние "поля для заполнения" при не раскрытом разделе',
#   0,
#   '',
#   '',
#   0],
#  3931492: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[QA][PPRC-1944] Написание тестовых сценариев',
#   0,
#   '',
#   '',
#   0],
#  3936169: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Вложения тест дизайн + тестирование (бэк)',
#   57600,
#   '',
#   '',
#   0],
#  3936191: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Вложения тест дизайн + тестирование (фронт)',
#   28800,
#   '',
#   '',
#   0],
#  3941779: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Связанные фрагменты',
#   3600,
#   '',
#   '',
#   0],
#  3959075: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Макрос Разделитель Тест кейсы',
#   86400,
#   '',
#   '',
#   0],
#  3960249: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Клонирование. В ответе при клонировании приходят параметры  sprint и actualSprint с идентичными значениями ',
#   86400,
#   '',
#   '',
#   0],
#  3961088: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Создание Таск трекер. Можно создать задачу в системном пространстве',
#   57600,
#   '',
#   '',
#   0],
#  3961291: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Создание Таск трекер. Можно создать задачу с привязанной задачей,  если в блоке relations есть дубликаты типов связей с одной задачей',
#   57600,
#   '',
#   '',
#   0],
#  3963619: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[AQA] Проставление тегов для автотестов по функциональности',
#   28800,
#   '',
#   '',
#   0],
#  3967007: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не работают связи с дочерними/связанными задачами',
#   60,
#   '',
#   '',
#   0],
#  3967031: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не открывается полноэкранная карточка, используется старый конфиг карточки для полноэкранной карточки',
#   60,
#   '',
#   '',
#   0],
#  3969519: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не работают date-time поля',
#   3600,
#   '',
#   '',
#   0],
#  3969553: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно осущствить списание трудозатрат',
#   3600,
#   '',
#   '',
#   0],
#  3969950: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка. Ошибка при загрузке страницы Бэклога после того, как пользователь списал время',
#   3600,
#   '',
#   '',
#   0],
#  3973197: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Поиск страниц - GET /pages',
#   57600,
#   '',
#   '',
#   0],
#  3975798: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Гант и Ворклог. В core-config произвести изменения, согласно новым требованиям',
#   14400,
#   '',
#   '',
#   0],
#  3978415: ['Система.Вики',
#   0,
#   0,
#   'Средний',
#   '[QA] Внешний API. Добавление ссылок к ресурсам (_links)',
#   28800,
#   '',
#   '',
#   0],
#  3979239: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. 500я ошибка при получении пользователей без авторизации',
#   28800,
#   '',
#   '',
#   0],
#  3979873: ['Система.Ошибки',
#   1,
#   2,
#   'Низкий',
#   '[BE] [П] В обращении, которое маршрутизировано в Система.Система1 не прописывается Код объекта (ID инцидента) в Система.',
#   144000,
#   '',
#   '',
#   0],
#  3982105: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Кнопка редактируемости фрагмента',
#   0,
#   '',
#   '',
#   0],
#  3982134: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Возможность создания полей в анкете шаблона (выбор варианта) (верстка)',
#   28800,
#   '',
#   '',
#   0],
#  3986221: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[SA] Учет рабочего времени. Описать работу функции hasWorklog',
#   3600,
#   '',
#   '',
#   0],
#  3986639: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[FE] [Конструктор карточки] При создании секции не должно быть размеров 22\\24 и 23\\24',
#   0,
#   '',
#   '',
#   0],
#  3987391: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Виртуальный скролл',
#   14400,
#   '',
#   '',
#   0],
#  3988216: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Сетка',
#   21600,
#   '',
#   '',
#   0],
#  3988352: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Шапка с датами / таймлайн',
#   14400,
#   '',
#   '',
#   0],
#  3988394: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Гранулярность',
#   7200,
#   '',
#   '',
#   0],
#  3988414: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Текущее время',
#   7200,
#   '',
#   '',
#   0],
#  3988868: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Синхронизация скролла',
#   10800,
#   '',
#   '',
#   0],
#  3988916: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Отображение спиннера закрузки',
#   3600,
#   '',
#   '',
#   0],
#  3988926: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Подсвечивание строки которая перетаскивается',
#   3600,
#   '',
#   '',
#   0],
#  3989100: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 2 связи. Разные виды связей и стрелки между задачами',
#   86400,
#   '',
#   '',
#   0],
#  3991034: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Фильтры на стартовом экране',
#   3600,
#   '',
#   '',
#   0],
#  3992849: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Копирование и вставка фрагментов',
#   0,
#   '',
#   '',
#   0],
#  3994050: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Отображение текущей версии Движока на стенде ч2',
#   28800,
#   '',
#   '',
#   0],
#  3995504: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[Core][FE][Редактор шаблона][Атрибуты] Ввод в поле параметров пробелы',
#   0,
#   '',
#   '',
#   0],
#  4003156: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Поиск на стартовой странице',
#   3600,
#   '',
#   '',
#   0],
#  4011600: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[С-Док][Анкета] Удаление основного файла с загруженной подписью  - поле с подписью не подсвечивается с ошибкой',
#   0,
#   '',
#   '',
#   0],
#  4012062: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Версионирование файлов',
#   576000,
#   '',
#   '',
#   0],
#  4013174: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC 2.0][PREPROD] Состав релиза. По умолчанию активны все колонки',
#   0,
#   '',
#   '',
#   0],
#  4022816: ['Система.Вики',
#   0,
#   1,
#   'Средний',
#   'Открытие пространства по его uuid',
#   60,
#   '',
#   '',
#   0],
#  4023424: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BE] Открытие пространства по его uuid',
#   28800,
#   '',
#   '',
#   0],
#  4025653: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[QA] APIv1. DELETE /api/v1/entities/{entityNumber}/attributes/{attribute}/{identifier}',
#   14400,
#   '',
#   '',
#   0],
#  4026364: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[QA] APIv1. GET /api/v1/entities/export - учесть поля с разными типами данных, а также системные',
#   0,
#   '',
#   '',
#   0],
#  4042153: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC 2.0][PREPROD] Тест-план. При заполнении Описания большим количеством символов текст отображается поверх таблицы',
#   0,
#   '',
#   '',
#   0],
#  4042394: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC-2.0][PREPROD] Тест-планы. Не отображается тултип при наведении на текст в колонке Описание.',
#   0,
#   '',
#   '',
#   0],
#  4050750: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[Core][FE][Редактор шаблона][Атрибуты] Текст тоста при ошибке получения атрибутов',
#   0,
#   '',
#   '',
#   0],
#  4056234: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Миграция карточки. Пропадают реакции к полям, если после миграции немного исправить сущность в админке атрибутов',
#   0,
#   '',
#   '',
#   0],
#  4056530: ['Система.Таск-трекер',
#   1,
#   1,
#   'Критический',
#   '[BE] Миграция карточки. Нет названий у атрибутов path, priority, status (нужна миграция на стороне нашего BE)',
#   0,
#   '',
#   '',
#   0],
#  4060389: ['Система.Таск-трекер',
#   1,
#   0,
#   'Критический',
#   '[BE] Миграция карточки. Не проставляется кастомный UI компонент автоматически для поля, в котором он имеется',
#   0,
#   '',
#   '',
#   0],
#  4060486: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[FE][Таблица] Пропадает рамка при перемещении клавишей SHIFT+TAB когда достигла колонки с автонумерацией',
#   3600,
#   '',
#   '',
#   0],
#  4065022: ['Система.Ошибки',
#   1,
#   2,
#   'Средний',
#   '[BE] [П] В инциденте дублируется одно и тоже вложение при добавлении вложения в обращение',
#   144000,
#   '',
#   '',
#   0],
#  4065300: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Доработка API на стороне core для получения статей СР при миграции из SM',
#   0,
#   '',
#   '',
#   0],
#  4067435: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BA] Модуль ссылок',
#   57600,
#   '',
#   '',
#   0],
#  4069882: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[PPRC][ПРОМ] (ex PPRC-2125, ADM-2840,  PPTS-7172) МП. Ошибка таймаута при выполнении вех у релизов с большим количеством историй',
#   115200,
#   '',
#   '',
#   0],
#  4070799: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Канбан. QL-фильтр при создании доски. Степпер',
#   43200,
#   '',
#   '',
#   0],
#  4070858: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Канбан. QL-фильтр при создании доски. QL инпут',
#   86400,
#   '',
#   '',
#   0],
#  4072346: ['Система.Таск-трекер',
#   1,
#   0,
#   'Средний',
#   '[FE] Структура. Гант. Селектор диапазона дат не позволяет выбрать дату в случае, если задана левая граница',
#   0,
#   '',
#   '',
#   0],
#  4072962: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Ответ 500 на запросы PATCH /api/v1/entities/history/disable и api/v1/entities/history/enable',
#   0,
#   '',
#   '',
#   0],
#  4075365: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   ' [QA] Канбан. QL-фильтр при создании доски. Тестирование',
#   86400,
#   '',
#   '',
#   0],
#  4075389: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   ' [QA] Канбан. Мультипространства.  Тестирование',
#   57600,
#   '',
#   '',
#   0],
#  4075629: ['Система. Движок',
#   1,
#   1,
#   'Средний',
#   '[BE] Зависимость модулей от core-rest-legacy',
#   0,
#   '',
#   '',
#   0],
#  4080416: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[BE] API v1. GET users. Нет образоподобия сортировки ответа при вызове API без параметра sort.',
#   0,
#   '',
#   '',
#   0],
#  4083382: ['Система. Движок',
#   0,
#   2,
#   'Критический',
#   '[QA] Патчи BE: 0.18.4 - 0.18.5',
#   28800,
#   '',
#   '',
#   0],
#  4083383: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Стартовый экран шаблонов',
#   3600,
#   '',
#   '',
#   0],
#  4083795: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[BE] API v1 - расширить attributeViews параметрами из entityTypes',
#   0,
#   '',
#   '',
#   0],
#  4087879: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[FE] Новые таблицы. Таск трекер. Лишний запрос на получение списка задач при переходе на представление Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4089534: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Автообновление на представлении "Бэклог"',
#   115200,
#   '',
#   '',
#   0],
#  4091652: ['Система. Движок',
#   1,
#   2,
#   'Высокий',
#   '[FE] [Конструктор карточки] Если при создании выбрать другой атрибут заполненые поля не сбрасываются',
#   0,
#   '',
#   '',
#   0],
#  4091655: ['Система. Движок',
#   1,
#   2,
#   'Высокий',
#   '[FE] [Конструктор карточки] При редактировании атрибута НЕ должно быть возможность поменять атрибут',
#   0,
#   '',
#   '',
#   0],
#  4092647: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] [Кафка] Интеграция с ДиР для передачи модели даных',
#   144000,
#   '',
#   '',
#   0],
#  4092837: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[FE] Интеграция с ДиР для администрирования правил UI компонента ГЭ',
#   0,
#   '',
#   '',
#   0],
#  4093617: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE]  QL трансформация запроса ',
#   86400,
#   '',
#   '',
#   0],
#  4093650: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE]   механизм применения и парсинга QL\xa0 выражения в ДиР ',
#   144000,
#   '',
#   '',
#   0],
#  4093732: ['Система. Движок',
#   0,
#   1,
#   'Средний',
#   '[BE] JsonPatch трансформация',
#   86400,
#   '',
#   '',
#   0],
#  4093973: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[Дефект][BE][PublicAPI]: PATCH /pages/{id} ошибка при обновлении контента если не указывать название страницы',
#   28800,
#   '',
#   '',
#   0],
#  4094771: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Файлы. Добавление mp4, 7z',
#   86400,
#   '',
#   '',
#   0],
#  4096572: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания полей в анкете шаблона (число, текст)',
#   3600,
#   '',
#   '',
#   0],
#  4097038: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Редактирование Таск трекер. 500я ошибка при редактировании несуществующей Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4098097: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Импорт.  Некорректные linked_relation_type у задач, дублируются views в пространстве',
#   0,
#   '',
#   '',
#   0],
#  4103291: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   ' [US] Заливка ячеек цветом. Экспорт ГОСТ',
#   0,
#   '',
#   '',
#   0],
#  4111553: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] APIv1. PATCH entities + ролёвка (тестирование + тест дизайн)',
#   86400,
#   '',
#   '',
#   0],
#  4117659: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  Экспорт ГОСТ многоуровневых списков в текстовых фрагментах',
#   0,
#   '',
#   '',
#   0],
#  4117720: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  Экспорт ГОСТ многоуровневых списков в табличных фрагментах',
#   0,
#   '',
#   '',
#   0],
#  4123739: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] 3 типа списка в сравнениях табличного фрагмента + экран сравнения публикаций (тестирование)',
#   43200,
#   '',
#   '',
#   0],
#  4127240: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Импорт. Не мпортируется проект из конкурент, если на стенде установлены неванильные конфиги (ошибка  Cannot deserialize value)',
#   0,
#   '',
#   '',
#   0],
#  4140096: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] Внешний API.  Комментарии (CRUD)',
#   86400,
#   '',
#   '',
#   0],
#  4142332: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA]  3 типа списка в сравнениях текстового фрагмента + экран сравнения публикаций (тестирование)',
#   43200,
#   '',
#   '',
#   0],
#  4142501: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][ПРОМ] При разрыве транзакций между с.Модуль и с.Таск трекер, релиз и вехи меняют свой статус',
#   0,
#   '',
#   '',
#   0],
#  4169281: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[Дефект][ПРОМ][FE] Не отображается блок кода во вложенной статье при наличии на странице PlantUML',
#   144000,
#   '',
#   '',
#   0],
#  4176602: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Модуль импорта. Отображается только 10 проектов из конкурент, не используется пагинация',
#   0,
#   '',
#   '',
#   0],
#  4178222: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[BE] Дашборд. Bulk PATCH при обновлении позиций/размеров нескольких виджетов',
#   28800,
#   '',
#   '',
#   0],
#  4189515: ['Система.Таск-трекер',
#   1,
#   0,
#   'Высокий',
#   '[FE] Администрирование. При удалении обязательных полей с карточки Таск трекер не появляется сообщение понятное администратору',
#   0,
#   '',
#   '',
#   0],
#  4193275: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно отредактировать значение в кастомном поле с типом DICTIONARY, невозможно создать задачу',
#   14400,
#   '',
#   '',
#   0],
#  4193304: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка. Некликабельные ключи задач в parent-chain',
#   14400,
#   '',
#   '',
#   0],
#  4193328: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Новая карточка. Невозможно скопировать ссылку на задачу по клику на номер этой Таск трекер или на кнопку в шапке Таск трекер',
#   14400,
#   '',
#   '',
#   0],
#  4193356: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Вложения. Добавление нового компонента вложений в новую карточку Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4197760: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Поддержка  большого кол-ва пользователей в спецразрешениях',
#   288000,
#   '',
#   '',
#   0],
#  4197866: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] Дизайн дока для Emitter - Eventual Consistency проекций FW ',
#   0,
#   '',
#   '',
#   0],
#  4200634: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[Core][FE][Редактор шаблона][Пользовательский фрагмент] После актуализации документа активна кнопка удаления фрагмента из кастом-группы',
#   0,
#   '',
#   '',
#   0],
#  4203803: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[BE]  API v1. GET attribute-views, атрибуты типа dictionary, user',
#   0,
#   '',
#   '',
#   0],
#  4205047: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[РЫНОК][Клиент] Макросы. После вставки макроса "Акцентированный блок" внутрь макроса "Раскрыть" нет возможности редактировать поле внутри макроса "Раскрыть". ',
#   28800,
#   '',
#   '',
#   0],
#  4205915: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка.  В карточке создания Таск трекер по умолчанию всегда выбрано пространство PPTS',
#   14400,
#   '',
#   '',
#   0],
#  4206030: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка.  Карточка Таск трекер выглядит полностью белой в Система.Таск трекер с канальным приложением',
#   0,
#   '',
#   '',
#   0],
#  4206109: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Администрирование. Некорректная цветовая схема используется в панели администрирования на стенде с канальным приложением',
#   0,
#   '',
#   '',
#   0],
#  4206312: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать задачу с заполненным полем с типом DATE',
#   3600,
#   '',
#   '',
#   0],
#  4206433: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новую метку в карточке создания Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4206473: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новый компонент в карточке создания Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4206517: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. При редактировании в карточке поля с типом DATE не отправляется запрос на бэк',
#   3600,
#   '',
#   '',
#   0],
#  4206678: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новый компонент в карточке редактирования Таск трекер, фронт не передает все необходимые параметры бэку',
#   7200,
#   '',
#   '',
#   0],
#  4206710: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Список компонент доступны для пространства не подгружается в карточку',
#   7200,
#   '',
#   '',
#   0],
#  4209474: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Новая карточка. Не отображается, кто создал/обновил задачу',
#   7200,
#   '',
#   '',
#   0],
#  4209484: ['Система.Таск-трекер',
#   1,
#   1,
#   'Критический',
#   '[РЫНОК][Клиент] Конструктор фильтров. Функция me() подставляется в некорректное место в запросе',
#   28800,
#   '',
#   '',
#   0],
#  4209553: ['Система.Таск-трекер',
#   1,
#   1,
#   'Средний',
#   '[РЫНОК][Клиент] История изменений. В истории изменений не фиксируются все изменения по задаче.',
#   57600,
#   '',
#   '',
#   0],
#  4210595: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. В запросе спринтов отсутствует параметр areaCode',
#   7200,
#   '',
#   '',
#   0],
#  4213680: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Разработать запрос GET api/v1/service-locator и GET api/v1/service-locator/{systemCode}',
#   115200,
#   '',
#   '',
#   0],
#  4215713: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[FE][Таблица] Автонумерация начинается с 0, если есть  стиль шапки таблицы не на первой строке ',
#   3600,
#   '',
#   '',
#   0],
#  4216758: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Контрол для ручного обновления таблиц на всех представлениях',
#   28800,
#   '',
#   '',
#   0],
#  4219251: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   ' [FE] Бэклог. Уходит 2 запроса на получение списка задач при переходе в представление Бэклог',
#   0,
#   '',
#   '',
#   0],
#  4219327: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Доски. Уходит 2 запроса на получение списка задач при переходе в представление Доски',
#   0,
#   '',
#   '',
#   0],
#  4219402: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Учет рабочего времени. Уходит 2 запроса на получения списка пользователей для гусеницы',
#   0,
#   '',
#   '',
#   0],
#  4221177: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[FE][Пользовательский фрагмент] В дропдауне ссылки всегда закрашен пункт "перейти по ссылке"',
#   3600,
#   '',
#   '',
#   0],
#  4223888: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Работы по установке кор фронта на стенды юрдоков',
#   0,
#   '',
#   '',
#   0],
#  4223889: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Возможность добавлять поля из анкеты в тело шаблона ',
#   0,
#   '',
#   '',
#   0],
#  4223901: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Релиз + Багофикс',
#   0,
#   '',
#   '',
#   0],
#  4223902: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Настройка шагов миграции шаблона с анкетой ',
#   0,
#   '',
#   '',
#   0],
#  4224671: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Копирование страниц (базовое, внутри пространства)',
#   86400,
#   '',
#   '',
#   0],
#  4227356: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   ' [С-Док][FE][Анкета] Нет красной галки в тосте если произошла ошибка при загрузке файла',
#   0,
#   '',
#   '',
#   0],
#  4227617: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Навигация между ячейками в режиме редактирования. Написание кейсов',
#   43200,
#   '',
#   '',
#   0],
#  4228331: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] Комментарии к версии страницы',
#   86400,
#   '',
#   '',
#   0],
#  4228784: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Получение кастомных полей. Статус код 500, если выполнить запрос без авторизации',
#   0,
#   '',
#   '',
#   0],
#  4228899: ['Система.Вики', 0, 2, 'Средний', '[QA] CSAT', 0, '', '', 0],
#  4229894: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] Копирование страниц: между пространствами',
#   86400,
#   '',
#   '',
#   0],
#  4229987: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BE] Копирование страниц: между пространствами',
#   0,
#   '',
#   '',
#   0],
#  4230520: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка меню с макросами и страницы. Написание тест кейсов',
#   86400,
#   '',
#   '',
#   0],
#  4230722: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[FE] Унификация табличных представлений',
#   0,
#   '',
#   '',
#   0],
#  4231388: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Экспорт в файл. Не выгружается родительская задача',
#   0,
#   '',
#   '',
#   0],
#  4231496: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPRC][BE] Обновить версию Движока до 0.16.8',
#   0,
#   '',
#   '',
#   0],
#  4233586: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[BE]  Некорректное выделение при добавлении инлайн-комментария ',
#   115200,
#   '',
#   '',
#   0],
#  4233693: ['Система. Движок',
#   0,
#   1,
#   'Средний',
#   '[BE] Исследовать варианты по трансформации ответа ',
#   144000,
#   '',
#   '',
#   0],
#  4234185: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Тестирование карточки: компоненты',
#   86400,
#   '',
#   '',
#   0],
#  4234338: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование карточки: зависимые поля',
#   0,
#   '',
#   '',
#   0],
#  4235057: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Массовое удаление фрагментов',
#   0,
#   '',
#   '',
#   0],
#  4243000: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование карточки: сквозной сценарий',
#   28800,
#   '',
#   '',
#   0],
#  4244878: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Импорт данных из документа формата DOCX в часть существующего документа',
#   115200,
#   '',
#   '',
#   0],
#  4247826: ['Система. Движок',
#   0,
#   2,
#   'Высокий',
#   '[AQA] BE автотесты: актуализация -  Простой CFO',
#   0,
#   '',
#   '',
#   0],
#  4260029: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   'КОПИЯ [FE] На странице файлы принимают вид битой картинки после настройки ограничения данного формата изображения для загрузки',
#   0,
#   '',
#   '',
#   0],
#  4261983: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Администрирование. Настройка сообщения 404, 500. Тестирование',
#   28800,
#   '',
#   '',
#   0],
#  4261993: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Администрирование. Настройка сообщения 404, 500. Тест-кейсы',
#   14400,
#   '',
#   '',
#   0],
#  4264603: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[SA] Добавление текстовых и строковых полей в таблицы.',
#   57600,
#   '',
#   '',
#   0],
#  4268216: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[AQA] Необходимо автоматизировать тест кейсы по внешнему АПИ ',
#   115200,
#   '',
#   '',
#   0],
#  4270368: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование. Админки + новый карточки',
#   50400,
#   '',
#   '',
#   0],
#  4274939: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Создание связанной Таск трекер. Можно указать в качестве родительской Таск трекер задачу из недоступного пространства',
#   0,
#   '',
#   '',
#   0],
#  4286112: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новые таблицы. Всегда запрашиваются Таск трекер для спринта и бэклога, если переходить из бэклога в какое-либо другое представление',
#   0,
#   '',
#   '',
#   0],
#  4302761: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Модуль импорта CSV. Тестирование',
#   57600,
#   '',
#   '',
#   0],
#  4309191: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] JsonPatch трансформация',
#   0,
#   '',
#   '',
#   0],
#  4309205: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA]   QL трансформация',
#   0,
#   '',
#   '',
#   0],
#  4309869: ['Управление релизами изменениями',
#   0,
#   1,
#   'Высокий',
#   '[PPRC-FW] Реализована функциональность адаптера СС.Аудит',
#   230400,
#   '',
#   '',
#   0],
#  4310172: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPRC-FW][BE] Подключить и настроить Аудит к Релизам',
#   0,
#   '',
#   '',
#   0],
#  4313378: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   "[FE] Вкладка Бэклог. Фильтрация задач в таблицах с помощью поиска по специальным символам. Символ '.",
#   0,
#   '',
#   '',
#   0],
#  4313531: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] API v1. Карточка Таск трекер. Нет перезапроса иерархической цепочки задач после удаления родительской Таск трекер в карточке редактирования',
#   0,
#   '',
#   '',
#   0],
#  4317040: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Файлы. Добавление mp4, 7z',
#   43200,
#   '',
#   '',
#   0],
#  4317095: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[FE]Кнопка "наверх" и кнопка виджета NPS/CSI',
#   0,
#   '',
#   '',
#   0],
#  4317974: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   'Дашборд. Установление WebSocket соединения',
#   547200,
#   '',
#   '',
#   0],
#  4317978: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд. Убрать зависисмости на Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4317979: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд 1.0. Убрать зависимости на окружение',
#   14400,
#   '',
#   '',
#   0],
#  4317981: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд 1.0. Удалить сертификат',
#   14400,
#   '',
#   '',
#   0],
#  4319042: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   'Дашборд. Создание подключения к источнику',
#   288000,
#   '',
#   '',
#   0],
#  4319047: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Api v1.История изменений. Не отображается история изменений при очистки спринта у Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4319076: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Хранение данных манифеста и подключения',
#   28800,
#   '',
#   '',
#   0],
#  4319968: ['Система.Таск-трекер',
#   1,
#   1,
#   'Средний',
#   '[BE] Карточка Таск трекер. Бэкэнд не выдает никакой ошибки при передаче даты в некорректном формате в поле DATE_TIME',
#   0,
#   '',
#   '',
#   0],
#  4323514: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] API v1. Конструктор фильтров. Подставляется ФИО пользователя а не логин при выборе пользователя в выпадающем списке для системных атрибутов createdBy  и updatedBy',
#   0,
#   '',
#   '',
#   0],
#  4325634: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание шаблонов',
#   0,
#   '',
#   '',
#   0],
#  4325748: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Доработка созданных шаблонов в json',
#   0,
#   '',
#   '',
#   0],
#  4325780: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание и редактирование документов с помощью анкеты (компоненты)',
#   0,
#   '',
#   '',
#   0],
#  4325847: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Интерполировать фрагменты документа из анкеты ',
#   0,
#   '',
#   '',
#   0],
#  4325892: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Справочник юрлиц',
#   0,
#   '',
#   '',
#   0],
#  4326388: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Стартовый экран шаблонов (верстка)',
#   86400,
#   '',
#   '',
#   0],
#  4326408: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Стартовый экран шаблонов (тест-кейсы)',
#   28800,
#   '',
#   '',
#   0],
#  4326440: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Стартовый экран шаблонов (тестирование)',
#   3600,
#   '',
#   '',
#   0],
#  4326531: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания и редактирования полей в анкете шаблона (дата, деньги) ',
#   3600,
#   '',
#   '',
#   0],
#  4326549: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Редактор шаблонов. Фильтры + Поиск на стартовом экране - приоритет 1',
#   14400,
#   '',
#   '',
#   0],
#  4326576: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Фильтры на стартовом экране',
#   43200,
#   '',
#   '',
#   0],
#  4326694: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Фильтры на стартовом экране (тест-кейсы)',
#   28800,
#   '',
#   '',
#   0],
#  4326715: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Фильтры на стартовом экране (тестирование)',
#   3600,
#   '',
#   '',
#   0],
#  4326752: ['Система.ХранениеАртефактов',
#   0,
#   2,
# ...
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Реализовать ванильный виджет',
#   86400,
#   '',
#   '',
#   0],
#  4509505: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Согласовать первый вариант контракта',
#   57600,
#   '',
#   '',
#   0],
#  4509511: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Реализация логики работы API PluginHub',
#   144000,
#   '',
#   '',
#   0],
#  4509516: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Разработка destroy SDK (отписки и тд)',
#   86400,
#   '',
#   '',
#   0],
#  4509518: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Обеспечить возможность работы с роутингом приложения',
#   86400,
#   '',
#   '',
#   0],
#  4509524: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Подготовить и опубликовать NPM пакеты',
#   0,
#   '',
#   '',
#   0],
#  4509530: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Разграничение загрузки плагинов для разных страниц в одной ИС',
#   144000,
#   '',
#   '',
#   0],
#  4509536: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция с ИС (Демо)',
#   144000,
#   '',
#   '',
#   0],
#  4509538: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Вычистить текущее решение плагинезации в С.Таск трекер',
#   144000,
#   '',
#   '',
#   0],
#  4509543: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Отладка библиотеки',
#   144000,
#   '',
#   '',
#   0],
#  4509547: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция плагинизации с С.Таск трекер',
#   288000,
#   '',
#   '',
#   0],
#  4509564: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция с С.Модуль',
#   288000,
#   '',
#   '',
#   0],
#  4509576: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Собрать стенд (Storybook) публикаций документации для потребителей',
#   201600,
#   '',
#   '',
#   0],
#  4509597: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[FE] [Копирование страниц] Невозможно запустить копирование для страницы на согласовании',
#   14400,
#   '',
#   '',
#   0],
#  4509854: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт конкурент. Не импортируются комментарии',
#   14400,
#   '',
#   '',
#   0],
#  4509857: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт. 500 server error, так как Таск трекер вернули пустой page с пространствами',
#   14400,
#   '',
#   '',
#   0],
#  4509868: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][BE] REST Client для работы с ПлагинХабом',
#   0,
#   '',
#   '',
#   0],
#  4509871: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPPL][BE] Реализация autodiscovery Точек расширения',
#   0,
#   '',
#   '',
#   0],
#  4509882: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPPL][BE] Обработчик Точек расширений',
#   144000,
#   '',
#   '',
#   0],
#  4509890: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона (число, текст) (верстка) (Ч2)',
#   28800,
#   '',
#   '',
#   0],
#  4510102: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[PPPL][ITL] Анализ разновидностей точек расширения',
#   432000,
#   '',
#   '',
#   0],
#  4510103: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[PPPL] Разработка точек расширений в Сф.Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4511013: ['Система.Вики',
#   1,
#   2,
#   'Высокий',
#   '[BE]Не работает раздел Просмотрено в Виджете Последние действия',
#   0,
#   '',
#   '',
#   0],
#  4511021: ['Система.Вики',
#   1,
#   1,
#   'Низкий',
#   '[FE]Подсказка с полным названием уходит за границу экрана',
#   0,
#   '',
#   '',
#   0],
#  4511830: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[FE] Вложения. Нет ховера по наведению на кнопку для загрузки вложения',
#   0,
#   '',
#   '',
#   0],
#  4511972: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '  [QA][AT] Макрос "Разделитель"',
#   86400,
#   '',
#   '',
#   0],
#  4512044: ['Управление релизами изменениями',
#   1,
#   2,
#   'Высокий',
#   '[PPRC 2.0][PREPROD] Состав релиза. Не отображается раздел "Состав релиза"',
#   0,
#   '',
#   '',
#   0],
#  4512383: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Отчет по тестированию сборки 1.19.0',
#   14400,
#   '',
#   '',
#   0],
#  4512596: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[FE] Невозможно переместить с дочерними страницу у которой есть родитель',
#   0,
#   '',
#   '',
#   0],
#  4512615: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Отладка SDK',
#   144000,
#   '',
#   '',
#   0],
#  4512624: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Настройка dev стенда в Компания (тестирование) Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4512637: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Кнопка редактируемости фрагмента. Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4513004: ['Система.Вики',
#   0,
#   1,
#   'Низкий',
#   '[ТехДолг][BE] Миграция. Клиент | Draw.io Confluence Plugin',
#   57600,
#   '',
#   '',
#   0],
#  4513018: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Создание плагина для юридических документов.Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4513204: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   'Хлебные крошки дублируются после того как появляется элемент три точки в них',
#   0,
#   '',
#   '',
#   0],
#  4513238: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт. Не работает импорт связей из CSV и последующая  перезапись данных на сборке Платформа.Таск-трекер.сервис2 4035-release-1.24',
#   14400,
#   '',
#   '',
#   0],
#  4513263: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[ТехДолг][BE] Миграция. Клиент | Draw.io Confluence Plugin',
#   57600,
#   '',
#   '',
#   0],
#  4514213: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[PPWI] Подключение к кафке сервиса metrics',
#   0,
#   '',
#   '',
#   0],
#  4514809: ['Система.Вики',
#   1,
#   1,
#   'Средний',
#   '[Дефект][ПРОМ][FE] не выделяются инлайн комментарии и не отображаются комментарии к ним на старых страницах ',
#   144000,
#   '',
#   '',
#   0],
#  4515732: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX/UI] Компонент SourceSelectFact и ObjectFact.Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4515746: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Юр.док. Редактор шаблона. Механизм вставки значений из анкеты в тело шаблона .Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4516028: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   'Неверный тип поля description в core-config',
#   0,
#   '',
#   '',
#   0],
#  4516073: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[UX] Иследование - Инструменты планирования (Глубинные)',
#   115200,
#   '',
#   '',
#   0],
#  4516118: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[UX] Подготовить макеты для тестирования',
#   0,
#   '',
#   '',
#   0],
#  4517025: ['Управление релизами изменениями',
#   1,
#   1,
#   'Средний',
#   '[PPRC][PROD] Есть возможность перевести релиз до статуса Успешно закрыт с незаполненным обязательным полем Изменяемые ИС',
#   0,
#   '',
#   '',
#   0],
#  4517382: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Пагинация/виртуализация в представлении "Бэклоги"',
#   28800,
#   '',
#   '',
#   0],
#  4518126: ['Система.Вики',
#   1,
#   1,
#   'Высокий',
#   '[FE]Не работает переход на страницу при клике на событие',
#   0,
#   '',
#   '',
#   0],
#  4520560: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2204] Написание тестовых сценариев.',
#   0,
#   '',
#   '',
#   0],
#  4520576: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2204] Выполнение тестовых сценариев',
#   0,
#   '',
#   '',
#   0],
#  4520829: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2267] Выполнить тестирование конфигурации форм',
#   0,
#   '',
#   '',
#   0],
#  4520932: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[ПРОМ][FE][Редактор] Пропадает разделение абзацев',
#   28800,
#   '',
#   '',
#   0],
#  4521377: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Geteway на GraalVM - сборка на TeamCity',
#   0,
#   '',
#   '',
#   0],
#  4521853: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] BFF: ТК для автоматизации',
#   86400,
#   '',
#   '',
#   0],
#  4521964: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Миграция карточки: ТК на BE и FE для автоматизации',
#   57600,
#   '',
#   '',
#   0],
#  4521974: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Поддержка настройки множественности атрибута в админке сущности и карточке',
#   0,
#   '',
#   '',
#   0],
#  4522012: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Поддержка настройки множественности атрибута в админке сущности + скрипт миграции',
#   0,
#   '',
#   '',
#   0],
#  4522218: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BA] Дашборд. Формат операций над сущностями',
#   0,
#   '',
#   '',
#   0],
#  4522310: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Реализация механизма ресайза и DnD виджетов гибкого экрана пользователем для настройки экрана под себя',
#   144000,
#   '',
#   '',
#   0],
#  4522318: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] СМ: тестирование и ТК для автоматизации',
#   86400,
#   '',
#   '',
#   0],
#  4522431: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Разбить сущности по типам со своими префиксами',
#   86400,
#   '',
#   '',
#   0],
#  4522452: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Создание единого стейта виджетов для оптимизации производительности',
#   144000,
#   '',
#   '',
#   0],
#  4522454: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Исследование проблем с word ',
#   28800,
#   '',
#   '',
#   0],
#  4522500: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Перенос кодовой базы FW стенда в основной репозиторий',
#   86400,
#   '',
#   '',
#   0],
#  4522536: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Сбор гибкого экрана на стенде со всеми имеющимися виджетами',
#   144000,
#   '',
#   '',
#   0],
#  4522591: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Ресерч новой архитектуры админок сущностей и аттрибутов',
#   0,
#   '',
#   '',
#   0],
#  4523718: ['Система. Движок',
#   0,
#   2,
#   'Критический',
#   '[QA] BE Поддержка настройки множественности атрибута в админке сущности + скрипт миграции',
#   0,
#   '',
#   '',
#   0],
#  4524193: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BA] Поддержка настройки множественности атрибута в админке сущности',
#   0,
#   '',
#   '',
#   0],
#  4524213: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[SA] Поддержка настройки множественности атрибута в админке сущности',
#   0,
#   '',
#   '',
#   0],
#  4524283: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Реализация механизма ресайза и DnD виджетов гибкого экрана пользователем для настройки экрана под себя',
#   0,
#   '',
#   '',
#   0],
#  4525683: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Редактор шаблонов. Архивация шаблонов',
#   14400,
#   '',
#   '',
#   0],
#  4525997: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Актуализация пагинации и виртуализации в таблице "Бэклоги"',
#   28800,
#   '',
#   '',
#   0],
#  4526142: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] CSP для макроса Код iframe',
#   86400,
#   '',
#   '',
#   0],
#  4526165: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] CSP для макроса Код iframe (админка)',
#   57600,
#   '',
#   '',
#   0],
#  4527191: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[BE] Дашборд. RnD: OIDC',
#   14400,
#   '',
#   '',
#   0],
#  4527255: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Трассировка требований  (разметка документов, требования, связи)',
#   57600,
#   '',
#   '',
#   0],
#  4527340: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Паспорт стрима',
#   14400,
#   '',
#   '',
#   0],
#  4527391: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Корпоративное управление',
#   14400,
#   '',
#   '',
#   0],
#  4527567: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис2',
#   3600,
#   '',
#   '',
#   0],
#  4527606: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис3',
#   3600,
#   '',
#   '',
#   0],
#  4527862: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис4',
#   0,
#   '',
#   '',
#   0],
#  4527875: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис5',
#   14400,
#   '',
#   '',
#   0],
#  4527891: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис6',
#   0,
#   '',
#   '',
#   0],
#  4528751: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Написать Dockerfile.storybook для запуска стенда с документацией',
#   28800,
#   '',
#   '',
#   0],
#  4529373: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   "При вставке макроса 'Дерево страниц' возникает 403 ошибка на запрос /pages ",
#   0,
#   '',
#   '',
#   0],
#  4529671: ['Система.ХранениеАртефактов',
#   0,
#   1,
#   'Средний',
#   '[QA] ПЦК Активности',
#   86400,
#   '',
#   '',
#   0],
#  4529684: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   'КОПИЯ [QA] Автоматизация (рефакторинг+написание)',
#   14400,
#   '',
#   '',
#   0],
#  4530754: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Демо Стандартные решения',
#   14400,
#   '',
#   '',
#   0],
#  4530886: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[demo][june] Не происходит смена статуса согласований из Таск трекер.',
#   0,
#   '',
#   '',
#   0],
#  4531037: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Можно создать задачу, если у Таск трекер нет статусной модели',
#   0,
#   '',
#   '',
#   0],
#  4531407: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Фрагмент LINK',
#   201600,
#   '',
#   '',
#   0],
#  4531412: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Юр.док.Доработка созданных шаблонов в json.Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4531490: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[FE] Дашборд. Нотификации',
#   14400,
#   '',
#   '',
#   0],
#  4531552: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[FE] Дашборд. Подключение к Канальному приложению',
#   57600,
#   '',
#   '',
#   0],
#  4531553: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Связаные фрагменты (POC)',
#   115200,
#   '',
#   '',
#   0],
#  4531616: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[DevOps][PPRC] Настроить TeamCity pipeline для развёртывания стенда с документацией (Storybook)',
#   0,
#   '',
#   '',
#   0],
#  4531653: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[FE] Дашборд. Удалить интеграции виджета Дашборда в Таск трекер',
#   28800,
#   '',
#   '',
#   0],
#  4531906: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Интеграционный плагин с Архитектурой',
#   57600,
#   '',
#   '',
#   0],
#  4531915: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Связаные фрагменты',
#   28800,
#   '',
#   '',
#   0],
#  4532022: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[UX] Статусные модели – подготовка исследования',
#   28800,
#   '',
#   '',
#   0],
#  4532093: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] 3 типа списка в сравнениях табличного фрагмента + экран сравнения публикаций (доработка)',
#   28800,
#   '',
#   '',
#   0],
#  4532094: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Админка для конфигов',
#   129600,
#   '',
#   '',
#   0],
#  4532215: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Проработка ограничения количества контента во фрагменте',
#   72000,
#   '',
#   '',
#   0],
#  4532640: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Создание Таск трекер из системного пространства. Избавиться от хардкода для пространства "Все"',
#   0,
#   '',
#   '',
#   0],
#  4532916: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Переезд на контур Компания (Тестирование после переезда, Helm чарты)',
#   3600,
#   '',
#   '',
#   0],
#  4533016: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Дашборд. Geteway на GraalVM',
#   28800,
#   '',
#   '',
#   0],
#  4533463: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Критический',
#   '[QA] [тест-кейсы] Миграция статей стандартных решений',
#   57600,
#   '',
#   '',
#   0],
#  4533508: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Ч2 Импорт данных из документа формата DOCX в часть существующего документа',
#   28800,
#   '',
#   '',
#   0],
#  4533564: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Добавление типов полей в таблицы - Поддержка экспорта',
#   0,
#   '',
#   '',
#   0],
#  ...}

# %%
history = get_lf("data/history-Table 1.csv").filter(
    pl.col("entity_id").is_not_null()
    & pl.col("history_property_name").is_not_null()
    & pl.col("history_property_name").is_in(["Статус", "Резолюция", "Спринт", "Связанные Задачи"])
).select(
    "entity_id", "history_property_name", "history_date", "history_change").collect()
history = history.with_columns(
    pl.col("history_date").str.to_datetime('%m/%d/%y %H:%M', time_unit="ms", strict=False)).with_columns(
    pl.col("history_change").str.split(" -> ").list.last()).sort(
    'history_date', maintain_order=True).with_columns(
    pl.col('history_change').shift(1).alias('history_change_prev')).with_columns(
    pl.col('entity_id').shift(1).alias('entity_id_prev')).with_columns(
    (pl.col("history_date").dt.timestamp("ms") // 86400000).alias("day"))

# %%
history.filter(pl.col("history_property_name") == "Резолюция")["history_change"].unique().to_list()
# Out:
# ['Готово', 'Отклонено', None, 'Дубликат', 'Отменен инициатором']

# %%
history["history_property_name"].unique().to_list()
# Out:
# ['Связанные Задачи', 'Статус', 'Спринт', 'Резолюция']

# %%
history
# Out:
# shape: (28_756, 7)
# ┌───────────┬───────────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────┐
# │ entity_id ┆ history_prope ┆ history_date  ┆ history_chang ┆ history_chang ┆ entity_id_pr ┆ day   │
# │ ---       ┆ rty_name      ┆ ---           ┆ e             ┆ e_prev        ┆ ev           ┆ ---   │
# │ i64       ┆ ---           ┆ datetime[ms]  ┆ ---           ┆ ---           ┆ ---          ┆ i64   │
# │           ┆ str           ┆               ┆ str           ┆ str           ┆ i64          ┆       │
# ╞═══════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════╡
# │ 1805925   ┆ Спринт        ┆ 2023-07-12    ┆ Спринт        ┆ null          ┆ null         ┆ 19550 │
# │           ┆               ┆ 13:29:00      ┆ 2023.3.2.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1805925   ┆ Спринт        ┆ 2023-07-31    ┆ null          ┆ Спринт        ┆ 1805925      ┆ 19569 │
# │           ┆               ┆ 17:43:00      ┆               ┆ 2023.3.2.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 1805925   ┆ Спринт        ┆ 2023-07-31    ┆ Спринт        ┆ null          ┆ 1805925      ┆ 19569 │
# │           ┆               ┆ 17:43:00      ┆ 2023.3.3.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ 8             ┆ Спринт        ┆ 1805925      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆ 2023.3.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ PPTS-3254     ┆ 8             ┆ 1934905      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆               ┆              ┆       │
# │ …         ┆ …             ┆ …             ┆ …             ┆ …             ┆ …            ┆ …     │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.3.6.NPP  ┆ 2024.3.4.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.1.NPP  ┆ 2024.3.6.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.2.NPP  ┆ 2024.4.1.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.3.NPP  ┆ 2024.4.2.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.4.NPP  ┆ 2024.4.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# └───────────┴───────────────┴───────────────┴───────────────┴───────────────┴──────────────┴───────┘

# %%
history.filter(pl.col("history_property_name") == "Статус")
# Out:
# shape: (6_964, 7)
# ┌───────────┬───────────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────┐
# │ entity_id ┆ history_prope ┆ history_date  ┆ history_chang ┆ history_chang ┆ entity_id_pr ┆ day   │
# │ ---       ┆ rty_name      ┆ ---           ┆ e             ┆ e_prev        ┆ ev           ┆ ---   │
# │ i64       ┆ ---           ┆ datetime[ms]  ┆ ---           ┆ ---           ┆ ---          ┆ i64   │
# │           ┆ str           ┆               ┆ str           ┆ str           ┆ i64          ┆       │
# ╞═══════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════╡
# │ 102481    ┆ Статус        ┆ 2023-10-23    ┆ analysis      ┆ null          ┆ 2441405      ┆ 19653 │
# │           ┆               ┆ 15:52:00      ┆               ┆               ┆              ┆       │
# │ 102481    ┆ Статус        ┆ 2023-10-24    ┆ design        ┆ Спринт        ┆ 2444222      ┆ 19654 │
# │           ┆               ┆ 15:27:00      ┆               ┆ 2023.4.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 102481    ┆ Статус        ┆ 2023-10-24    ┆ analysis      ┆ design        ┆ 102481       ┆ 19654 │
# │           ┆               ┆ 15:27:00      ┆               ┆               ┆              ┆       │
# │ 102481    ┆ Статус        ┆ 2023-10-30    ┆ design        ┆ analysis      ┆ 102481       ┆ 19660 │
# │           ┆               ┆ 14:13:00      ┆               ┆               ┆              ┆       │
# │ 102481    ┆ Статус        ┆ 2023-10-30    ┆ readyForDevel ┆ design        ┆ 102481       ┆ 19660 │
# │           ┆               ┆ 14:13:00      ┆ opment        ┆               ┆              ┆       │
# │ …         ┆ …             ┆ …             ┆ …             ┆ …             ┆ …            ┆ …     │
# │ 4600573   ┆ Статус        ┆ 2024-11-02    ┆ testing       ┆ verification  ┆ 4914666      ┆ 20029 │
# │           ┆               ┆ 07:01:00      ┆               ┆               ┆              ┆       │
# │ 4956270   ┆ Статус        ┆ 2024-11-02    ┆ analysis      ┆ testing       ┆ 4600573      ┆ 20029 │
# │           ┆               ┆ 08:05:00      ┆               ┆               ┆              ┆       │
# │ 4681026   ┆ Статус        ┆ 2024-11-02    ┆ testing       ┆ analysis      ┆ 4956270      ┆ 20029 │
# │           ┆               ┆ 11:33:00      ┆               ┆               ┆              ┆       │
# │ 4937920   ┆ Статус        ┆ 2024-11-02    ┆ testing       ┆ testing       ┆ 4681026      ┆ 20029 │
# │           ┆               ┆ 12:09:00      ┆               ┆               ┆              ┆       │
# │ 4697963   ┆ Статус        ┆ 2024-11-06    ┆ created       ┆ Спринт        ┆ 4697963      ┆ 20033 │
# │           ┆               ┆ 07:08:00      ┆               ┆ 2024.4.4.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# └───────────┴───────────────┴───────────────┴───────────────┴───────────────┴──────────────┴───────┘

# %%
entities
# Out:
# {94297: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Бэклог. Кастомизация колонок. Кастомизация для панелей "спринты" и  "бэклоги" зависима друг от друга',
#   60,
#   '',
#   '',
#   0],
#  102481: ['Система.Ошибки',
#   0,
#   2,
#   'Критический',
#   '[ГенераторДокументов] Интеграция со Система.ГенераторДокументов в части синхронизации Стандартных решений',
#   432000,
#   '',
#   '',
#   0],
#  1805925: ['Система.Таск-трекер',
#   1,
#   1,
#   'Высокий',
#   '[FE] История изменений. Пустые строки в истории изменений, если выбрать значение, которое уже было выбрано до редактирования поля',
#   60,
#   '',
#   '',
#   0],
#  1934905: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Зависимые поля. Тип реакции disable НЕ работает для некоторых типов полей',
#   0,
#   '',
#   '',
#   0],
#  1943849: ['Система.Ошибки',
#   1,
#   2,
#   'Низкий',
#   '[BE] При сортировке по Теме если знаки препинания стоят перед буквенными значениями сортировка отрабатывает неправильно',
#   0,
#   '',
#   '',
#   0],
#  1966759: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC][PREPROD] При незаполненном обязательном поле Изменяемые ИС текст под полем некорректный',
#   0,
#   '',
#   '',
#   0],
#  2353124: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Паспорт стрима (печатная форма)',
#   3600,
#   '',
#   '',
#   0],
#  2383243: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Настройка dev стенда в Компания',
#   3600,
#   '',
#   '',
#   0],
#  2441405: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC][ST] ЗНУ. При попытке создать ЗНУ пользователем без прав появляется и исчезает шторка создания ЗНУ. ',
#   0,
#   '',
#   '',
#   0],
#  2444222: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-Док][FE][Публикация] Левое меню публикации',
#   0,
#   '',
#   '',
#   0],
#  2503655: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[BE] Синхронизация стандартных решений из Система.ГенераторДокументов',
#   0,
#   '',
#   '',
#   0],
#  2536878: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[Дефект] [FE] Теги. При тегировании несуществующего пользователя нет текста "Нет совпадений"',
#   28800,
#   '',
#   '',
#   0],
#  2540151: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт документа формата DOCX',
#   0,
#   '',
#   '',
#   0],
#  2582366: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] [PREPROD](fixed 1.28.0) Бэклог. Не работает ввод пробела при поиске спринтов в панели спринтов',
#   0,
#   '',
#   '',
#   0],
#  2623949: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API (error responses)',
#   28800,
#   '',
#   '',
#   0],
#  2824925: ['Система.Ошибки',
#   0,
#   2,
#   'Высокий',
#   '[ML Инц-2] Группировка инцидентов с помощью ML-модели',
#   144000,
#   '',
#   '',
#   0],
#  2840563: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Таск трекер. Задублированные запросы personal-settings с фронта на представлениях Таск трекер и Бэклог',
#   0,
#   '',
#   '',
#   0],
#  2867204: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] API v1 Получение полной сущности со смаппленными кодами на универсальную модель справочника ',
#   57600,
#   '',
#   '',
#   0],
#  2887761: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[СДок][BE][Иерархия заголовков] Разный шрифт для заголовков',
#   7200,
#   '',
#   '',
#   0],
#  2938657: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] История изменений. Метки и компоненты. Некорректно отображение состава и статуса изменений меток и компонентов в истории изменений',
#   0,
#   '',
#   '',
#   0],
#  2970791: ['Система.Таск-трекер',
#   1,
#   1,
#   'Низкий',
#   '[FE] Структура. Нельзя закрыть выпадающие списки в окне создания и редактирования структуры кликом на шеврон для раскрытия/ закрытия списка',
#   0,
#   '',
#   '',
#   0],
#  2980909: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   ' [QA] Интеграция Система.Конфигурации',
#   144000,
#   '',
#   '',
#   0],
#  2995479: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-док][FE][Анкета]  "Представление модели части объекта" - расширение файла',
#   14400,
#   '',
#   '',
#   0],
#  3027722: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Конструктор фильтров. Функция me() подставляется в некорректное место в запросе , если она была выбрана внутри дропдауна',
#   0,
#   '',
#   '',
#   0],
#  3051159: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[AQA] Обновить в тестовых сущностях поля, связанные с релизами',
#   28800,
#   '',
#   '',
#   0],
#  3057885: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[FE] Группировка инцидентов с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3127873: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1  entity-types. Некорректный текст сообщения при обновлении не обновляемого атрибута типа сущности',
#   0,
#   '',
#   '',
#   0],
#  3130955: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание плагина для юридических документов',
#   3600,
#   '',
#   '',
#   0],
#  3185895: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Скролл в таблице',
#   57600,
#   '',
#   '',
#   0],
#  3206897: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE][Техдолг] Проработать механизм работы с моками',
#   57600,
#   '',
#   '',
#   0],
#  3207618: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Макрос Код iframe',
#   60,
#   '',
#   '',
#   0],
#  3207737: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Структура. Фронт не запрашивает порцию задач с page=0 после добавления/ удаления колонки на экране',
#   0,
#   '',
#   '',
#   0],
#  3315188: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE]Структура. Не обновляется updateDate после изменения структуры.',
#   14400,
#   '',
#   '',
#   0],
#  3332524: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[BE] Инвистигация АПИ ОПС для виджета NPS',
#   28800,
#   '',
#   '',
#   0],
#  3335475: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Добавление макроса, редактирование, шторка',
#   28800,
#   '',
#   '',
#   0],
#  3335507: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Ресайз (рамка + абсолютное значение)',
#   14400,
#   '',
#   '',
#   0],
#  3335563: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Запрет на взаимодействие с другими макросами',
#   28800,
#   '',
#   '',
#   0],
#  3335577: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] [Макрос Код iframe] Запрет на копирование макроса',
#   14400,
#   '',
#   '',
#   0],
#  3335613: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] [Макрос Код iframe] Тест кейсы ',
#   144000,
#   '',
#   '',
#   0],
#  3385299: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Карточка Таск трекер. Статус код 500 при загрузке вложений',
#   0,
#   '',
#   '',
#   0],
#  3421421: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  3 типа списка в сравнениях текстового фрагмента + экран сравнения публикаций',
#   0,
#   '',
#   '',
#   0],
#  3424881: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт многоуровневых списков в текстовый фрагмент',
#   3600,
#   '',
#   '',
#   0],
#  3481977: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. Создание структуры без привязки к пространству.',
#   0,
#   '',
#   '',
#   0],
#  3482014: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. Создание структуры к несуществующему пространству.',
#   0,
#   '',
#   '',
#   0],
#  3493071: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '  [Дефект] [FE]  Не работает инлайн -комментарий  в заголовке макроса "Акцентированный блок"',
#   28800,
#   '',
#   '',
#   0],
#  3502800: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Низкий',
#   '[С-док][Создание документа] При выходе из просмотра документа, в теле документа отображаются спец. символы',
#   0,
#   '',
#   '',
#   0],
#  3508978: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Структура. Приложение зависает, если добавить/ удалить колонку в структуре и в этой структуре под её настройки попало менее 51-й Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  3516665: ['Система.Таск-трекер',
#   1,
#   1,
#   'Высокий',
#   '[BE] Не обновляются данные пользователя в entities.properties если данные пользовтаеля изменились в users (в AD)',
#   0,
#   '',
#   '',
#   0],
#  3533870: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Фильтрация. Не работает поиск пользователей в поле Исполнитель',
#   0,
#   '',
#   '',
#   0],
#  3549113: ['Управление релизами изменениями',
#   1,
#   1,
#   'Низкий',
#   '[PPRC 2.0] [ST][PREPROD] Таблица. В табличном отображении по умолчанию отображаются все колонки.',
#   0,
#   '',
#   '',
#   0],
#  3549401: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Настройка обязательности атрибутов шаблона',
#   0,
#   '',
#   '',
#   0],
#  3588880: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE][Техдолг]  Удалить старый код по черновику',
#   14400,
#   '',
#   '',
#   0],
#  3604826: ['Система. Движок',
#   1,
#   1,
#   'Средний',
#   '[BE] GET  v1/entitites/{entityNum}/attributes/relations/{id} с несуществующей сущностью в entityNum возвращает 200',
#   0,
#   '',
#   '',
#   0],
#  3620274: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD]МП. Веха "Провести ИФТ" скорректировать уведомление ',
#   0,
#   '',
#   '',
#   0],
#  3625924: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[С-док][FE][Цветная Валидация]При сохрании раздела с файлом без подписи нет цветной валидации',
#   57600,
#   '',
#   '',
#   0],
#  3626050: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[С-док][FE][Цветная Валидация]Поля с файлами и подписью не подсвечиваются при разных названиях ',
#   0,
#   '',
#   '',
#   0],
#  3641264: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] Модуль процессов. Отсутствует информация в тосте о количестве задач, не прошедших проверку ',
#   0,
#   '',
#   '',
#   0],
#  3641304: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] Модуль процессов. В тосте о количестве задач, не прошедших проверку лишний текст ',
#   0,
#   '',
#   '',
#   0],
#  3671384: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC][PREPROD] МП. При отсутствии значения атрибута Использует ДК по ИС всплывает сообщение с нечитаемой ошибкой ',
#   0,
#   '',
#   '',
#   0],
#  3675079: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][PREPROD] МП. Отсутствует тост об успешном выполнении запроса после получения ответа от МП',
#   0,
#   '',
#   '',
#   0],
#  3681164: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] История изменений. Отображается пустая история изменений удалении файла, который имеет то же имя и расширение, как и ранее удаленный',
#   0,
#   '',
#   '',
#   0],
#  3681209: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] История изменений. Отображается некорректная история изменений при удалении ВСЕХ вложений',
#   0,
#   '',
#   '',
#   0],
#  3689670: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] APIv1. Тестирование + тест дизайн. Получение /v1/sprints',
#   57600,
#   '',
#   '',
#   0],
#  3701003: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Один и тот же статус можно использовать в разных колонках',
#   0,
#   '',
#   '',
#   0],
#  3723915: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Экспорт многоуровневых списков в табличных фрагментах',
#   3600,
#   '',
#   '',
#   0],
#  3724161: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Импорт многоуровневых списков в табличный фрагмент',
#   3600,
#   '',
#   '',
#   0],
#  3725698: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Таблицы. Копирование строк/столбцов',
#   950400,
#   '',
#   '',
#   0],
#  3749735: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Низкий',
#   '[С-док][FE][Анкета] Скролл к разделу не происходит ',
#   0,
#   '',
#   '',
#   0],
#  3757374: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Общее: трассировка запрсоов (X-Request-Id)',
#   28800,
#   '',
#   '',
#   0],
#  3781039: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[ПЗ][US] Переезд в контур Компания',
#   3600,
#   '',
#   '',
#   0],
#  3791006: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Структура. GET/ fields. В ответе приходит по 2 поля spent, estimation, remainder',
#   0,
#   '',
#   '',
#   0],
#  3796983: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] Макрос: Календарь',
#   115200,
#   '',
#   '',
#   0],
#  3797131: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Учёт рабочего времени. История изменений по модулю учёта рабочего времени',
#   57600,
#   '',
#   '',
#   0],
#  3798425: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[FE] [Управления сущностями] Не обрабатывается ошибка когда данные с бэка не подгружаются',
#   0,
#   '',
#   '',
#   0],
#  3799650: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[AQA] Техдолг по макросу Акцентированный блок',
#   28800,
#   '',
#   '',
#   0],
#  3803163: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[AQA] Автоматизация тест-кейсов по Структуре (FE)',
#   86400,
#   '',
#   '',
#   0],
#  3815067: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   "[AQA] Автоматизация общих тест-кейсов для представления 'Доски'.",
#   86400,
#   '',
#   '',
#   0],
#  3815680: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC][PREPROD] МП. При повторном действии по МП во время его выполнения всплывает неинформативное сообщение с ошибкой',
#   0,
#   '',
#   '',
#   0],
#  3818307: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[С-док][FE]При скачивании файла/подписи файла на кнопках крутится лоадер',
#   0,
#   '',
#   '',
#   0],
#  3818753: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Виджет Недавние действия. Тести рование и тест кейсы',
#   144000,
#   '',
#   '',
#   0],
#  3823975: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность редактирования/сохранения полей в анкете шаблона (число, текст, дата, деньги) ',
#   3600,
#   '',
#   '',
#   0],
#  3824296: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Возможность создания и редактирования полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3825345: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Тест дизайн + тестирование (BE) - Создание дочерней и связанной Таск трекер из родительской',
#   28800,
#   '',
#   '',
#   0],
#  3826504: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Копирование и вставка группы с включенными детьми',
#   0,
#   '',
#   '',
#   0],
#  3828992: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Поиск страниц - POST /pages/get-by-id',
#   28800,
#   '',
#   '',
#   0],
#  3829019: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Копирование строк/столбцов, корнер кейсы',
#   86400,
#   '',
#   '',
#   0],
#  3829030: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Копирование строк/столбцов через hotkeys',
#   28800,
#   '',
#   '',
#   0],
#  3829039: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[FE] Таблицы. Вставка скопированных строк/столбцов вне таблицы',
#   57600,
#   '',
#   '',
#   0],
#  3829052: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API.  Получение списка пространств',
#   28800,
#   '',
#   '',
#   0],
#  3829067: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Копирование строк/столбцов. Тестирование часть 1',
#   86400,
#   '',
#   '',
#   0],
#  3829076: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Копирование строк/столбцов. Тест-кейсы. ч2',
#   144000,
#   '',
#   '',
#   0],
#  3830127: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   57600,
#   '',
#   '',
#   0],
#  3830128: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Возможность создания полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3836390: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Возможность создания полей в анкете шаблона  (справочник (одиночный и множественный выбор)) ',
#   43200,
#   '',
#   '',
#   0],
#  3836437: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания и редактирования полей в анкете шаблона (справочник (одиночный и множественный выбор))',
#   3600,
#   '',
#   '',
#   0],
#  3837909: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Перемещение фрагментов',
#   0,
#   '',
#   '',
#   0],
#  3841940: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Возможность создания и редактирования полей в анкете шаблона (выбор варианта) ',
#   14400,
#   '',
#   '',
#   0],
#  3842914: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Управление доступом к страницам',
#   28800,
#   '',
#   '',
#   0],
#  3847317: ['Система.Вики',
#   0,
#   2,
#   'Низкий',
#   '[UX] Редактор 2.0: Компонент рамки макросов',
#   57600,
#   '',
#   '',
#   0],
#  3864586: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[SA] Привязка инцидентов к проблеме с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3864762: ['Система.Ошибки',
#   0,
#   2,
#   'Средний',
#   '[QA] Привязка инцидентов к проблеме с помощью ИИ',
#   0,
#   '',
#   '',
#   0],
#  3890401: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка инпута названия (просмотр)',
#   14400,
#   '',
#   '',
#   0],
#  3890402: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка инпута названия (редактирование)',
#   28800,
#   '',
#   '',
#   0],
#  3902314: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Back module для коммуникации FW->FW',
#   57600,
#   '',
#   '',
#   0],
#  3907488: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Сделать Emitter для Eventual Consistency проекций FW ',
#   288000,
#   '',
#   '',
#   0],
#  3907493: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] Сделать Consumer для Eventual Consistency проекций FW',
#   115200,
#   '',
#   '',
#   0],
#  3910233: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Карточка Таск трекер. Учет рабочего времени. Нет тоста для Участника пространства (кот.имеет глобальную роль) при попытке списаться в даты закрытого спринта',
#   57600,
#   '',
#   '',
#   0],
#  3910459: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона (кнопка, выбор варианта)',
#   86400,
#   '',
#   '',
#   0],
#  3910470: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Заливка ячеек цветом. Импорт',
#   0,
#   '',
#   '',
#   0],
#  3910535: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Дополнительные атрибуты публикации для статей стандартных решений',
#   0,
#   '',
#   '',
#   0],
#  3913376: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[С-док][FE][Анкета]В превью отображаются лишние "поля для заполнения" при не раскрытом разделе',
#   0,
#   '',
#   '',
#   0],
#  3931492: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[QA][PPRC-1944] Написание тестовых сценариев',
#   0,
#   '',
#   '',
#   0],
#  3936169: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Вложения тест дизайн + тестирование (бэк)',
#   57600,
#   '',
#   '',
#   0],
#  3936191: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Вложения тест дизайн + тестирование (фронт)',
#   28800,
#   '',
#   '',
#   0],
#  3941779: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Связанные фрагменты',
#   3600,
#   '',
#   '',
#   0],
#  3959075: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Макрос Разделитель Тест кейсы',
#   86400,
#   '',
#   '',
#   0],
#  3960249: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Клонирование. В ответе при клонировании приходят параметры  sprint и actualSprint с идентичными значениями ',
#   86400,
#   '',
#   '',
#   0],
#  3961088: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Создание Таск трекер. Можно создать задачу в системном пространстве',
#   57600,
#   '',
#   '',
#   0],
#  3961291: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Создание Таск трекер. Можно создать задачу с привязанной задачей,  если в блоке relations есть дубликаты типов связей с одной задачей',
#   57600,
#   '',
#   '',
#   0],
#  3963619: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[AQA] Проставление тегов для автотестов по функциональности',
#   28800,
#   '',
#   '',
#   0],
#  3967007: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не работают связи с дочерними/связанными задачами',
#   60,
#   '',
#   '',
#   0],
#  3967031: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не открывается полноэкранная карточка, используется старый конфиг карточки для полноэкранной карточки',
#   60,
#   '',
#   '',
#   0],
#  3969519: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Не работают date-time поля',
#   3600,
#   '',
#   '',
#   0],
#  3969553: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно осущствить списание трудозатрат',
#   3600,
#   '',
#   '',
#   0],
#  3969950: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка. Ошибка при загрузке страницы Бэклога после того, как пользователь списал время',
#   3600,
#   '',
#   '',
#   0],
#  3973197: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Внешний API. Поиск страниц - GET /pages',
#   57600,
#   '',
#   '',
#   0],
#  3975798: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Гант и Ворклог. В core-config произвести изменения, согласно новым требованиям',
#   14400,
#   '',
#   '',
#   0],
#  3978415: ['Система.Вики',
#   0,
#   0,
#   'Средний',
#   '[QA] Внешний API. Добавление ссылок к ресурсам (_links)',
#   28800,
#   '',
#   '',
#   0],
#  3979239: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. 500я ошибка при получении пользователей без авторизации',
#   28800,
#   '',
#   '',
#   0],
#  3979873: ['Система.Ошибки',
#   1,
#   2,
#   'Низкий',
#   '[BE] [П] В обращении, которое маршрутизировано в Система.Система1 не прописывается Код объекта (ID инцидента) в Система.',
#   144000,
#   '',
#   '',
#   0],
#  3982105: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Кнопка редактируемости фрагмента',
#   0,
#   '',
#   '',
#   0],
#  3982134: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Возможность создания полей в анкете шаблона (выбор варианта) (верстка)',
#   28800,
#   '',
#   '',
#   0],
#  3986221: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[SA] Учет рабочего времени. Описать работу функции hasWorklog',
#   3600,
#   '',
#   '',
#   0],
#  3986639: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[FE] [Конструктор карточки] При создании секции не должно быть размеров 22\\24 и 23\\24',
#   0,
#   '',
#   '',
#   0],
#  3987391: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Виртуальный скролл',
#   14400,
#   '',
#   '',
#   0],
#  3988216: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Сетка',
#   21600,
#   '',
#   '',
#   0],
#  3988352: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Шапка с датами / таймлайн',
#   14400,
#   '',
#   '',
#   0],
#  3988394: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Гранулярность',
#   7200,
#   '',
#   '',
#   0],
#  3988414: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Текущее время',
#   7200,
#   '',
#   '',
#   0],
#  3988868: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Синхронизация скролла',
#   10800,
#   '',
#   '',
#   0],
#  3988916: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Отображение спиннера закрузки',
#   3600,
#   '',
#   '',
#   0],
#  3988926: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 1 Фон. Подсвечивание строки которая перетаскивается',
#   3600,
#   '',
#   '',
#   0],
#  3989100: ['Система.Таск-трекер',
#   0,
#   0,
#   'Высокий',
#   '[FE] Гант. Базовый компонент. Контейнер. Слой 2 связи. Разные виды связей и стрелки между задачами',
#   86400,
#   '',
#   '',
#   0],
#  3991034: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Фильтры на стартовом экране',
#   3600,
#   '',
#   '',
#   0],
#  3992849: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Копирование и вставка фрагментов',
#   0,
#   '',
#   '',
#   0],
#  3994050: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Отображение текущей версии Движока на стенде ч2',
#   28800,
#   '',
#   '',
#   0],
#  3995504: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[Core][FE][Редактор шаблона][Атрибуты] Ввод в поле параметров пробелы',
#   0,
#   '',
#   '',
#   0],
#  4003156: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Поиск на стартовой странице',
#   3600,
#   '',
#   '',
#   0],
#  4011600: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[С-Док][Анкета] Удаление основного файла с загруженной подписью  - поле с подписью не подсвечивается с ошибкой',
#   0,
#   '',
#   '',
#   0],
#  4012062: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Версионирование файлов',
#   576000,
#   '',
#   '',
#   0],
#  4013174: ['Управление релизами изменениями',
#   1,
#   2,
#   'Средний',
#   '[PPRC 2.0][PREPROD] Состав релиза. По умолчанию активны все колонки',
#   0,
#   '',
#   '',
#   0],
#  4022816: ['Система.Вики',
#   0,
#   1,
#   'Средний',
#   'Открытие пространства по его uuid',
#   60,
#   '',
#   '',
#   0],
#  4023424: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BE] Открытие пространства по его uuid',
#   28800,
#   '',
#   '',
#   0],
#  4025653: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[QA] APIv1. DELETE /api/v1/entities/{entityNumber}/attributes/{attribute}/{identifier}',
#   14400,
#   '',
#   '',
#   0],
#  4026364: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[QA] APIv1. GET /api/v1/entities/export - учесть поля с разными типами данных, а также системные',
#   0,
#   '',
#   '',
#   0],
#  4042153: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC 2.0][PREPROD] Тест-план. При заполнении Описания большим количеством символов текст отображается поверх таблицы',
#   0,
#   '',
#   '',
#   0],
#  4042394: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC-2.0][PREPROD] Тест-планы. Не отображается тултип при наведении на текст в колонке Описание.',
#   0,
#   '',
#   '',
#   0],
#  4050750: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[Core][FE][Редактор шаблона][Атрибуты] Текст тоста при ошибке получения атрибутов',
#   0,
#   '',
#   '',
#   0],
#  4056234: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Миграция карточки. Пропадают реакции к полям, если после миграции немного исправить сущность в админке атрибутов',
#   0,
#   '',
#   '',
#   0],
#  4056530: ['Система.Таск-трекер',
#   1,
#   1,
#   'Критический',
#   '[BE] Миграция карточки. Нет названий у атрибутов path, priority, status (нужна миграция на стороне нашего BE)',
#   0,
#   '',
#   '',
#   0],
#  4060389: ['Система.Таск-трекер',
#   1,
#   0,
#   'Критический',
#   '[BE] Миграция карточки. Не проставляется кастомный UI компонент автоматически для поля, в котором он имеется',
#   0,
#   '',
#   '',
#   0],
#  4060486: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[FE][Таблица] Пропадает рамка при перемещении клавишей SHIFT+TAB когда достигла колонки с автонумерацией',
#   3600,
#   '',
#   '',
#   0],
#  4065022: ['Система.Ошибки',
#   1,
#   2,
#   'Средний',
#   '[BE] [П] В инциденте дублируется одно и тоже вложение при добавлении вложения в обращение',
#   144000,
#   '',
#   '',
#   0],
#  4065300: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Доработка API на стороне core для получения статей СР при миграции из SM',
#   0,
#   '',
#   '',
#   0],
#  4067435: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BA] Модуль ссылок',
#   57600,
#   '',
#   '',
#   0],
#  4069882: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[PPRC][ПРОМ] (ex PPRC-2125, ADM-2840,  PPTS-7172) МП. Ошибка таймаута при выполнении вех у релизов с большим количеством историй',
#   115200,
#   '',
#   '',
#   0],
#  4070799: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Канбан. QL-фильтр при создании доски. Степпер',
#   43200,
#   '',
#   '',
#   0],
#  4070858: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Канбан. QL-фильтр при создании доски. QL инпут',
#   86400,
#   '',
#   '',
#   0],
#  4072346: ['Система.Таск-трекер',
#   1,
#   0,
#   'Средний',
#   '[FE] Структура. Гант. Селектор диапазона дат не позволяет выбрать дату в случае, если задана левая граница',
#   0,
#   '',
#   '',
#   0],
#  4072962: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Ответ 500 на запросы PATCH /api/v1/entities/history/disable и api/v1/entities/history/enable',
#   0,
#   '',
#   '',
#   0],
#  4075365: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   ' [QA] Канбан. QL-фильтр при создании доски. Тестирование',
#   86400,
#   '',
#   '',
#   0],
#  4075389: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   ' [QA] Канбан. Мультипространства.  Тестирование',
#   57600,
#   '',
#   '',
#   0],
#  4075629: ['Система. Движок',
#   1,
#   1,
#   'Средний',
#   '[BE] Зависимость модулей от core-rest-legacy',
#   0,
#   '',
#   '',
#   0],
#  4080416: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[BE] API v1. GET users. Нет образоподобия сортировки ответа при вызове API без параметра sort.',
#   0,
#   '',
#   '',
#   0],
#  4083382: ['Система. Движок',
#   0,
#   2,
#   'Критический',
#   '[QA] Патчи BE: 0.18.4 - 0.18.5',
#   28800,
#   '',
#   '',
#   0],
#  4083383: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Редактор шаблонов. Стартовый экран шаблонов',
#   3600,
#   '',
#   '',
#   0],
#  4083795: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[BE] API v1 - расширить attributeViews параметрами из entityTypes',
#   0,
#   '',
#   '',
#   0],
#  4087879: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[FE] Новые таблицы. Таск трекер. Лишний запрос на получение списка задач при переходе на представление Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4089534: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Автообновление на представлении "Бэклог"',
#   115200,
#   '',
#   '',
#   0],
#  4091652: ['Система. Движок',
#   1,
#   2,
#   'Высокий',
#   '[FE] [Конструктор карточки] Если при создании выбрать другой атрибут заполненые поля не сбрасываются',
#   0,
#   '',
#   '',
#   0],
#  4091655: ['Система. Движок',
#   1,
#   2,
#   'Высокий',
#   '[FE] [Конструктор карточки] При редактировании атрибута НЕ должно быть возможность поменять атрибут',
#   0,
#   '',
#   '',
#   0],
#  4092647: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] [Кафка] Интеграция с ДиР для передачи модели даных',
#   144000,
#   '',
#   '',
#   0],
#  4092837: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[FE] Интеграция с ДиР для администрирования правил UI компонента ГЭ',
#   0,
#   '',
#   '',
#   0],
#  4093617: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE]  QL трансформация запроса ',
#   86400,
#   '',
#   '',
#   0],
#  4093650: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE]   механизм применения и парсинга QL\xa0 выражения в ДиР ',
#   144000,
#   '',
#   '',
#   0],
#  4093732: ['Система. Движок',
#   0,
#   1,
#   'Средний',
#   '[BE] JsonPatch трансформация',
#   86400,
#   '',
#   '',
#   0],
#  4093973: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[Дефект][BE][PublicAPI]: PATCH /pages/{id} ошибка при обновлении контента если не указывать название страницы',
#   28800,
#   '',
#   '',
#   0],
#  4094771: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Файлы. Добавление mp4, 7z',
#   86400,
#   '',
#   '',
#   0],
#  4096572: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания полей в анкете шаблона (число, текст)',
#   3600,
#   '',
#   '',
#   0],
#  4097038: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Редактирование Таск трекер. 500я ошибка при редактировании несуществующей Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4098097: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Импорт.  Некорректные linked_relation_type у задач, дублируются views в пространстве',
#   0,
#   '',
#   '',
#   0],
#  4103291: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   ' [US] Заливка ячеек цветом. Экспорт ГОСТ',
#   0,
#   '',
#   '',
#   0],
#  4111553: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] APIv1. PATCH entities + ролёвка (тестирование + тест дизайн)',
#   86400,
#   '',
#   '',
#   0],
#  4117659: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  Экспорт ГОСТ многоуровневых списков в текстовых фрагментах',
#   0,
#   '',
#   '',
#   0],
#  4117720: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US]  Экспорт ГОСТ многоуровневых списков в табличных фрагментах',
#   0,
#   '',
#   '',
#   0],
#  4123739: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] 3 типа списка в сравнениях табличного фрагмента + экран сравнения публикаций (тестирование)',
#   43200,
#   '',
#   '',
#   0],
#  4127240: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Импорт. Не мпортируется проект из конкурент, если на стенде установлены неванильные конфиги (ошибка  Cannot deserialize value)',
#   0,
#   '',
#   '',
#   0],
#  4140096: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] Внешний API.  Комментарии (CRUD)',
#   86400,
#   '',
#   '',
#   0],
#  4142332: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA]  3 типа списка в сравнениях текстового фрагмента + экран сравнения публикаций (тестирование)',
#   43200,
#   '',
#   '',
#   0],
#  4142501: ['Управление релизами изменениями',
#   1,
#   2,
#   'Низкий',
#   '[PPRC][ПРОМ] При разрыве транзакций между с.Модуль и с.Таск трекер, релиз и вехи меняют свой статус',
#   0,
#   '',
#   '',
#   0],
#  4169281: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[Дефект][ПРОМ][FE] Не отображается блок кода во вложенной статье при наличии на странице PlantUML',
#   144000,
#   '',
#   '',
#   0],
#  4176602: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Модуль импорта. Отображается только 10 проектов из конкурент, не используется пагинация',
#   0,
#   '',
#   '',
#   0],
#  4178222: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[BE] Дашборд. Bulk PATCH при обновлении позиций/размеров нескольких виджетов',
#   28800,
#   '',
#   '',
#   0],
#  4189515: ['Система.Таск-трекер',
#   1,
#   0,
#   'Высокий',
#   '[FE] Администрирование. При удалении обязательных полей с карточки Таск трекер не появляется сообщение понятное администратору',
#   0,
#   '',
#   '',
#   0],
#  4193275: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно отредактировать значение в кастомном поле с типом DICTIONARY, невозможно создать задачу',
#   14400,
#   '',
#   '',
#   0],
#  4193304: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка. Некликабельные ключи задач в parent-chain',
#   14400,
#   '',
#   '',
#   0],
#  4193328: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Новая карточка. Невозможно скопировать ссылку на задачу по клику на номер этой Таск трекер или на кнопку в шапке Таск трекер',
#   14400,
#   '',
#   '',
#   0],
#  4193356: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Вложения. Добавление нового компонента вложений в новую карточку Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4197760: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   'Поддержка  большого кол-ва пользователей в спецразрешениях',
#   288000,
#   '',
#   '',
#   0],
#  4197866: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[BE] Дизайн дока для Emitter - Eventual Consistency проекций FW ',
#   0,
#   '',
#   '',
#   0],
#  4200634: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[Core][FE][Редактор шаблона][Пользовательский фрагмент] После актуализации документа активна кнопка удаления фрагмента из кастом-группы',
#   0,
#   '',
#   '',
#   0],
#  4203803: ['Система. Движок',
#   1,
#   2,
#   'Средний',
#   '[BE]  API v1. GET attribute-views, атрибуты типа dictionary, user',
#   0,
#   '',
#   '',
#   0],
#  4205047: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[РЫНОК][Клиент] Макросы. После вставки макроса "Акцентированный блок" внутрь макроса "Раскрыть" нет возможности редактировать поле внутри макроса "Раскрыть". ',
#   28800,
#   '',
#   '',
#   0],
#  4205915: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка.  В карточке создания Таск трекер по умолчанию всегда выбрано пространство PPTS',
#   14400,
#   '',
#   '',
#   0],
#  4206030: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новая карточка.  Карточка Таск трекер выглядит полностью белой в Система.Таск трекер с канальным приложением',
#   0,
#   '',
#   '',
#   0],
#  4206109: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Администрирование. Некорректная цветовая схема используется в панели администрирования на стенде с канальным приложением',
#   0,
#   '',
#   '',
#   0],
#  4206312: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать задачу с заполненным полем с типом DATE',
#   3600,
#   '',
#   '',
#   0],
#  4206433: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новую метку в карточке создания Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4206473: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новый компонент в карточке создания Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4206517: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. При редактировании в карточке поля с типом DATE не отправляется запрос на бэк',
#   3600,
#   '',
#   '',
#   0],
#  4206678: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Невозможно создать новый компонент в карточке редактирования Таск трекер, фронт не передает все необходимые параметры бэку',
#   7200,
#   '',
#   '',
#   0],
#  4206710: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. Список компонент доступны для пространства не подгружается в карточку',
#   7200,
#   '',
#   '',
#   0],
#  4209474: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Новая карточка. Не отображается, кто создал/обновил задачу',
#   7200,
#   '',
#   '',
#   0],
#  4209484: ['Система.Таск-трекер',
#   1,
#   1,
#   'Критический',
#   '[РЫНОК][Клиент] Конструктор фильтров. Функция me() подставляется в некорректное место в запросе',
#   28800,
#   '',
#   '',
#   0],
#  4209553: ['Система.Таск-трекер',
#   1,
#   1,
#   'Средний',
#   '[РЫНОК][Клиент] История изменений. В истории изменений не фиксируются все изменения по задаче.',
#   57600,
#   '',
#   '',
#   0],
#  4210595: ['Система.Таск-трекер',
#   1,
#   2,
#   'Критический',
#   '[FE] Новая карточка. В запросе спринтов отсутствует параметр areaCode',
#   7200,
#   '',
#   '',
#   0],
#  4213680: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Разработать запрос GET api/v1/service-locator и GET api/v1/service-locator/{systemCode}',
#   115200,
#   '',
#   '',
#   0],
#  4215713: ['Система.ХранениеАртефактов',
#   1,
#   1,
#   'Средний',
#   '[FE][Таблица] Автонумерация начинается с 0, если есть  стиль шапки таблицы не на первой строке ',
#   3600,
#   '',
#   '',
#   0],
#  4216758: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Контрол для ручного обновления таблиц на всех представлениях',
#   28800,
#   '',
#   '',
#   0],
#  4219251: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   ' [FE] Бэклог. Уходит 2 запроса на получение списка задач при переходе в представление Бэклог',
#   0,
#   '',
#   '',
#   0],
#  4219327: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Доски. Уходит 2 запроса на получение списка задач при переходе в представление Доски',
#   0,
#   '',
#   '',
#   0],
#  4219402: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] Учет рабочего времени. Уходит 2 запроса на получения списка пользователей для гусеницы',
#   0,
#   '',
#   '',
#   0],
#  4221177: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Средний',
#   '[FE][Пользовательский фрагмент] В дропдауне ссылки всегда закрашен пункт "перейти по ссылке"',
#   3600,
#   '',
#   '',
#   0],
#  4223888: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Работы по установке кор фронта на стенды юрдоков',
#   0,
#   '',
#   '',
#   0],
#  4223889: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Возможность добавлять поля из анкеты в тело шаблона ',
#   0,
#   '',
#   '',
#   0],
#  4223901: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Релиз + Багофикс',
#   0,
#   '',
#   '',
#   0],
#  4223902: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Настройка шагов миграции шаблона с анкетой ',
#   0,
#   '',
#   '',
#   0],
#  4224671: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Копирование страниц (базовое, внутри пространства)',
#   86400,
#   '',
#   '',
#   0],
#  4227356: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   ' [С-Док][FE][Анкета] Нет красной галки в тосте если произошла ошибка при загрузке файла',
#   0,
#   '',
#   '',
#   0],
#  4227617: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Таблицы. Навигация между ячейками в режиме редактирования. Написание кейсов',
#   43200,
#   '',
#   '',
#   0],
#  4228331: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] Комментарии к версии страницы',
#   86400,
#   '',
#   '',
#   0],
#  4228784: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Получение кастомных полей. Статус код 500, если выполнить запрос без авторизации',
#   0,
#   '',
#   '',
#   0],
#  4228899: ['Система.Вики', 0, 2, 'Средний', '[QA] CSAT', 0, '', '', 0],
#  4229894: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] Копирование страниц: между пространствами',
#   86400,
#   '',
#   '',
#   0],
#  4229987: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BE] Копирование страниц: между пространствами',
#   0,
#   '',
#   '',
#   0],
#  4230520: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Переработка меню с макросами и страницы. Написание тест кейсов',
#   86400,
#   '',
#   '',
#   0],
#  4230722: ['Система.Таск-трекер',
#   0,
#   0,
#   'Средний',
#   '[FE] Унификация табличных представлений',
#   0,
#   '',
#   '',
#   0],
#  4231388: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Экспорт в файл. Не выгружается родительская задача',
#   0,
#   '',
#   '',
#   0],
#  4231496: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPRC][BE] Обновить версию Движока до 0.16.8',
#   0,
#   '',
#   '',
#   0],
#  4233586: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[BE]  Некорректное выделение при добавлении инлайн-комментария ',
#   115200,
#   '',
#   '',
#   0],
#  4233693: ['Система. Движок',
#   0,
#   1,
#   'Средний',
#   '[BE] Исследовать варианты по трансформации ответа ',
#   144000,
#   '',
#   '',
#   0],
#  4234185: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Тестирование карточки: компоненты',
#   86400,
#   '',
#   '',
#   0],
#  4234338: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование карточки: зависимые поля',
#   0,
#   '',
#   '',
#   0],
#  4235057: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Массовое удаление фрагментов',
#   0,
#   '',
#   '',
#   0],
#  4243000: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование карточки: сквозной сценарий',
#   28800,
#   '',
#   '',
#   0],
#  4244878: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Импорт данных из документа формата DOCX в часть существующего документа',
#   115200,
#   '',
#   '',
#   0],
#  4247826: ['Система. Движок',
#   0,
#   2,
#   'Высокий',
#   '[AQA] BE автотесты: актуализация -  Простой CFO',
#   0,
#   '',
#   '',
#   0],
#  4260029: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   'КОПИЯ [FE] На странице файлы принимают вид битой картинки после настройки ограничения данного формата изображения для загрузки',
#   0,
#   '',
#   '',
#   0],
#  4261983: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Администрирование. Настройка сообщения 404, 500. Тестирование',
#   28800,
#   '',
#   '',
#   0],
#  4261993: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Администрирование. Настройка сообщения 404, 500. Тест-кейсы',
#   14400,
#   '',
#   '',
#   0],
#  4264603: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[SA] Добавление текстовых и строковых полей в таблицы.',
#   57600,
#   '',
#   '',
#   0],
#  4268216: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[AQA] Необходимо автоматизировать тест кейсы по внешнему АПИ ',
#   115200,
#   '',
#   '',
#   0],
#  4270368: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Тестирование. Админки + новый карточки',
#   50400,
#   '',
#   '',
#   0],
#  4274939: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Создание связанной Таск трекер. Можно указать в качестве родительской Таск трекер задачу из недоступного пространства',
#   0,
#   '',
#   '',
#   0],
#  4286112: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Новые таблицы. Всегда запрашиваются Таск трекер для спринта и бэклога, если переходить из бэклога в какое-либо другое представление',
#   0,
#   '',
#   '',
#   0],
#  4302761: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Модуль импорта CSV. Тестирование',
#   57600,
#   '',
#   '',
#   0],
#  4309191: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] JsonPatch трансформация',
#   0,
#   '',
#   '',
#   0],
#  4309205: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA]   QL трансформация',
#   0,
#   '',
#   '',
#   0],
#  4309869: ['Управление релизами изменениями',
#   0,
#   1,
#   'Высокий',
#   '[PPRC-FW] Реализована функциональность адаптера СС.Аудит',
#   230400,
#   '',
#   '',
#   0],
#  4310172: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPRC-FW][BE] Подключить и настроить Аудит к Релизам',
#   0,
#   '',
#   '',
#   0],
#  4313378: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   "[FE] Вкладка Бэклог. Фильтрация задач в таблицах с помощью поиска по специальным символам. Символ '.",
#   0,
#   '',
#   '',
#   0],
#  4313531: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] API v1. Карточка Таск трекер. Нет перезапроса иерархической цепочки задач после удаления родительской Таск трекер в карточке редактирования',
#   0,
#   '',
#   '',
#   0],
#  4317040: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Файлы. Добавление mp4, 7z',
#   43200,
#   '',
#   '',
#   0],
#  4317095: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[FE]Кнопка "наверх" и кнопка виджета NPS/CSI',
#   0,
#   '',
#   '',
#   0],
#  4317974: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   'Дашборд. Установление WebSocket соединения',
#   547200,
#   '',
#   '',
#   0],
#  4317978: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд. Убрать зависисмости на Таск трекер',
#   7200,
#   '',
#   '',
#   0],
#  4317979: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд 1.0. Убрать зависимости на окружение',
#   14400,
#   '',
#   '',
#   0],
#  4317981: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Дашборд 1.0. Удалить сертификат',
#   14400,
#   '',
#   '',
#   0],
#  4319042: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   'Дашборд. Создание подключения к источнику',
#   288000,
#   '',
#   '',
#   0],
#  4319047: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] Api v1.История изменений. Не отображается история изменений при очистки спринта у Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4319076: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Хранение данных манифеста и подключения',
#   28800,
#   '',
#   '',
#   0],
#  4319968: ['Система.Таск-трекер',
#   1,
#   1,
#   'Средний',
#   '[BE] Карточка Таск трекер. Бэкэнд не выдает никакой ошибки при передаче даты в некорректном формате в поле DATE_TIME',
#   0,
#   '',
#   '',
#   0],
#  4323514: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[FE] API v1. Конструктор фильтров. Подставляется ФИО пользователя а не логин при выборе пользователя в выпадающем списке для системных атрибутов createdBy  и updatedBy',
#   0,
#   '',
#   '',
#   0],
#  4325634: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание шаблонов',
#   0,
#   '',
#   '',
#   0],
#  4325748: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Доработка созданных шаблонов в json',
#   0,
#   '',
#   '',
#   0],
#  4325780: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Создание и редактирование документов с помощью анкеты (компоненты)',
#   0,
#   '',
#   '',
#   0],
#  4325847: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Интерполировать фрагменты документа из анкеты ',
#   0,
#   '',
#   '',
#   0],
#  4325892: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Справочник юрлиц',
#   0,
#   '',
#   '',
#   0],
#  4326388: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Стартовый экран шаблонов (верстка)',
#   86400,
#   '',
#   '',
#   0],
#  4326408: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Стартовый экран шаблонов (тест-кейсы)',
#   28800,
#   '',
#   '',
#   0],
#  4326440: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Стартовый экран шаблонов (тестирование)',
#   3600,
#   '',
#   '',
#   0],
#  4326531: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[US] Возможность создания и редактирования полей в анкете шаблона (дата, деньги) ',
#   3600,
#   '',
#   '',
#   0],
#  4326549: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Редактор шаблонов. Фильтры + Поиск на стартовом экране - приоритет 1',
#   14400,
#   '',
#   '',
#   0],
#  4326576: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Фильтры на стартовом экране',
#   43200,
#   '',
#   '',
#   0],
#  4326694: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Фильтры на стартовом экране (тест-кейсы)',
#   28800,
#   '',
#   '',
#   0],
#  4326715: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Редактор шаблонов. Фильтры на стартовом экране (тестирование)',
#   3600,
#   '',
#   '',
#   0],
#  4326752: ['Система.ХранениеАртефактов',
#   0,
#   2,
# ...
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Реализовать ванильный виджет',
#   86400,
#   '',
#   '',
#   0],
#  4509505: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Согласовать первый вариант контракта',
#   57600,
#   '',
#   '',
#   0],
#  4509511: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Реализация логики работы API PluginHub',
#   144000,
#   '',
#   '',
#   0],
#  4509516: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Разработка destroy SDK (отписки и тд)',
#   86400,
#   '',
#   '',
#   0],
#  4509518: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Обеспечить возможность работы с роутингом приложения',
#   86400,
#   '',
#   '',
#   0],
#  4509524: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Подготовить и опубликовать NPM пакеты',
#   0,
#   '',
#   '',
#   0],
#  4509530: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Разграничение загрузки плагинов для разных страниц в одной ИС',
#   144000,
#   '',
#   '',
#   0],
#  4509536: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция с ИС (Демо)',
#   144000,
#   '',
#   '',
#   0],
#  4509538: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Вычистить текущее решение плагинезации в С.Таск трекер',
#   144000,
#   '',
#   '',
#   0],
#  4509543: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Отладка библиотеки',
#   144000,
#   '',
#   '',
#   0],
#  4509547: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция плагинизации с С.Таск трекер',
#   288000,
#   '',
#   '',
#   0],
#  4509564: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Интеграция с С.Модуль',
#   288000,
#   '',
#   '',
#   0],
#  4509576: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Собрать стенд (Storybook) публикаций документации для потребителей',
#   201600,
#   '',
#   '',
#   0],
#  4509597: ['Система.Вики',
#   1,
#   2,
#   'Низкий',
#   '[FE] [Копирование страниц] Невозможно запустить копирование для страницы на согласовании',
#   14400,
#   '',
#   '',
#   0],
#  4509854: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт конкурент. Не импортируются комментарии',
#   14400,
#   '',
#   '',
#   0],
#  4509857: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт. 500 server error, так как Таск трекер вернули пустой page с пространствами',
#   14400,
#   '',
#   '',
#   0],
#  4509868: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][BE] REST Client для работы с ПлагинХабом',
#   0,
#   '',
#   '',
#   0],
#  4509871: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPPL][BE] Реализация autodiscovery Точек расширения',
#   0,
#   '',
#   '',
#   0],
#  4509882: ['Управление релизами изменениями',
#   0,
#   2,
#   'Высокий',
#   '[PPPL][BE] Обработчик Точек расширений',
#   144000,
#   '',
#   '',
#   0],
#  4509890: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Возможность создания и редактирования полей в анкете шаблона (число, текст) (верстка) (Ч2)',
#   28800,
#   '',
#   '',
#   0],
#  4510102: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[PPPL][ITL] Анализ разновидностей точек расширения',
#   432000,
#   '',
#   '',
#   0],
#  4510103: ['Управление релизами изменениями',
#   0,
#   1,
#   'Средний',
#   '[PPPL] Разработка точек расширений в Сф.Таск трекер',
#   0,
#   '',
#   '',
#   0],
#  4511013: ['Система.Вики',
#   1,
#   2,
#   'Высокий',
#   '[BE]Не работает раздел Просмотрено в Виджете Последние действия',
#   0,
#   '',
#   '',
#   0],
#  4511021: ['Система.Вики',
#   1,
#   1,
#   'Низкий',
#   '[FE]Подсказка с полным названием уходит за границу экрана',
#   0,
#   '',
#   '',
#   0],
#  4511830: ['Система.Таск-трекер',
#   1,
#   2,
#   'Низкий',
#   '[FE] Вложения. Нет ховера по наведению на кнопку для загрузки вложения',
#   0,
#   '',
#   '',
#   0],
#  4511972: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '  [QA][AT] Макрос "Разделитель"',
#   86400,
#   '',
#   '',
#   0],
#  4512044: ['Управление релизами изменениями',
#   1,
#   2,
#   'Высокий',
#   '[PPRC 2.0][PREPROD] Состав релиза. Не отображается раздел "Состав релиза"',
#   0,
#   '',
#   '',
#   0],
#  4512383: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[QA] Отчет по тестированию сборки 1.19.0',
#   14400,
#   '',
#   '',
#   0],
#  4512596: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   '[FE] Невозможно переместить с дочерними страницу у которой есть родитель',
#   0,
#   '',
#   '',
#   0],
#  4512615: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Отладка SDK',
#   144000,
#   '',
#   '',
#   0],
#  4512624: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Настройка dev стенда в Компания (тестирование) Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4512637: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Редактор шаблонов. Кнопка редактируемости фрагмента. Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4513004: ['Система.Вики',
#   0,
#   1,
#   'Низкий',
#   '[ТехДолг][BE] Миграция. Клиент | Draw.io Confluence Plugin',
#   57600,
#   '',
#   '',
#   0],
#  4513018: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Создание плагина для юридических документов.Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4513204: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   'Хлебные крошки дублируются после того как появляется элемент три точки в них',
#   0,
#   '',
#   '',
#   0],
#  4513238: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[BE] Импорт. Не работает импорт связей из CSV и последующая  перезапись данных на сборке Платформа.Таск-трекер.сервис2 4035-release-1.24',
#   14400,
#   '',
#   '',
#   0],
#  4513263: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[ТехДолг][BE] Миграция. Клиент | Draw.io Confluence Plugin',
#   57600,
#   '',
#   '',
#   0],
#  4514213: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[PPWI] Подключение к кафке сервиса metrics',
#   0,
#   '',
#   '',
#   0],
#  4514809: ['Система.Вики',
#   1,
#   1,
#   'Средний',
#   '[Дефект][ПРОМ][FE] не выделяются инлайн комментарии и не отображаются комментарии к ним на старых страницах ',
#   144000,
#   '',
#   '',
#   0],
#  4515732: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX/UI] Компонент SourceSelectFact и ObjectFact.Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4515746: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Юр.док. Редактор шаблона. Механизм вставки значений из анкеты в тело шаблона .Ч2',
#   28800,
#   '',
#   '',
#   0],
#  4516028: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   'Неверный тип поля description в core-config',
#   0,
#   '',
#   '',
#   0],
#  4516073: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[UX] Иследование - Инструменты планирования (Глубинные)',
#   115200,
#   '',
#   '',
#   0],
#  4516118: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[UX] Подготовить макеты для тестирования',
#   0,
#   '',
#   '',
#   0],
#  4517025: ['Управление релизами изменениями',
#   1,
#   1,
#   'Средний',
#   '[PPRC][PROD] Есть возможность перевести релиз до статуса Успешно закрыт с незаполненным обязательным полем Изменяемые ИС',
#   0,
#   '',
#   '',
#   0],
#  4517382: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Пагинация/виртуализация в представлении "Бэклоги"',
#   28800,
#   '',
#   '',
#   0],
#  4518126: ['Система.Вики',
#   1,
#   1,
#   'Высокий',
#   '[FE]Не работает переход на страницу при клике на событие',
#   0,
#   '',
#   '',
#   0],
#  4520560: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2204] Написание тестовых сценариев.',
#   0,
#   '',
#   '',
#   0],
#  4520576: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2204] Выполнение тестовых сценариев',
#   0,
#   '',
#   '',
#   0],
#  4520829: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[QA][PPRC-2267] Выполнить тестирование конфигурации форм',
#   0,
#   '',
#   '',
#   0],
#  4520932: ['Система.ХранениеАртефактов',
#   1,
#   2,
#   'Низкий',
#   '[ПРОМ][FE][Редактор] Пропадает разделение абзацев',
#   28800,
#   '',
#   '',
#   0],
#  4521377: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Geteway на GraalVM - сборка на TeamCity',
#   0,
#   '',
#   '',
#   0],
#  4521853: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] BFF: ТК для автоматизации',
#   86400,
#   '',
#   '',
#   0],
#  4521964: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Миграция карточки: ТК на BE и FE для автоматизации',
#   57600,
#   '',
#   '',
#   0],
#  4521974: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Поддержка настройки множественности атрибута в админке сущности и карточке',
#   0,
#   '',
#   '',
#   0],
#  4522012: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BE] Поддержка настройки множественности атрибута в админке сущности + скрипт миграции',
#   0,
#   '',
#   '',
#   0],
#  4522218: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BA] Дашборд. Формат операций над сущностями',
#   0,
#   '',
#   '',
#   0],
#  4522310: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Реализация механизма ресайза и DnD виджетов гибкого экрана пользователем для настройки экрана под себя',
#   144000,
#   '',
#   '',
#   0],
#  4522318: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[QA] СМ: тестирование и ТК для автоматизации',
#   86400,
#   '',
#   '',
#   0],
#  4522431: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[BE] Разбить сущности по типам со своими префиксами',
#   86400,
#   '',
#   '',
#   0],
#  4522452: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Создание единого стейта виджетов для оптимизации производительности',
#   144000,
#   '',
#   '',
#   0],
#  4522454: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[QA] Исследование проблем с word ',
#   28800,
#   '',
#   '',
#   0],
#  4522500: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Перенос кодовой базы FW стенда в основной репозиторий',
#   86400,
#   '',
#   '',
#   0],
#  4522536: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Сбор гибкого экрана на стенде со всеми имеющимися виджетами',
#   144000,
#   '',
#   '',
#   0],
#  4522591: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[FE] Ресерч новой архитектуры админок сущностей и аттрибутов',
#   0,
#   '',
#   '',
#   0],
#  4523718: ['Система. Движок',
#   0,
#   2,
#   'Критический',
#   '[QA] BE Поддержка настройки множественности атрибута в админке сущности + скрипт миграции',
#   0,
#   '',
#   '',
#   0],
#  4524193: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[BA] Поддержка настройки множественности атрибута в админке сущности',
#   0,
#   '',
#   '',
#   0],
#  4524213: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[SA] Поддержка настройки множественности атрибута в админке сущности',
#   0,
#   '',
#   '',
#   0],
#  4524283: ['Система. Движок',
#   0,
#   0,
#   'Средний',
#   '[QA] Реализация механизма ресайза и DnD виджетов гибкого экрана пользователем для настройки экрана под себя',
#   0,
#   '',
#   '',
#   0],
#  4525683: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[UX] Редактор шаблонов. Архивация шаблонов',
#   14400,
#   '',
#   '',
#   0],
#  4525997: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[FE] Актуализация пагинации и виртуализации в таблице "Бэклоги"',
#   28800,
#   '',
#   '',
#   0],
#  4526142: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[BA] CSP для макроса Код iframe',
#   86400,
#   '',
#   '',
#   0],
#  4526165: ['Система.Вики',
#   0,
#   2,
#   'Средний',
#   '[UX] CSP для макроса Код iframe (админка)',
#   57600,
#   '',
#   '',
#   0],
#  4527191: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[BE] Дашборд. RnD: OIDC',
#   14400,
#   '',
#   '',
#   0],
#  4527255: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Трассировка требований  (разметка документов, требования, связи)',
#   57600,
#   '',
#   '',
#   0],
#  4527340: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Паспорт стрима',
#   14400,
#   '',
#   '',
#   0],
#  4527391: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Корпоративное управление',
#   14400,
#   '',
#   '',
#   0],
#  4527567: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис2',
#   3600,
#   '',
#   '',
#   0],
#  4527606: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис3',
#   3600,
#   '',
#   '',
#   0],
#  4527862: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис4',
#   0,
#   '',
#   '',
#   0],
#  4527875: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис5',
#   14400,
#   '',
#   '',
#   0],
#  4527891: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Дашборд. Actuator: Платформа.Сервис6',
#   0,
#   '',
#   '',
#   0],
#  4528751: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[PPPL][FE] Написать Dockerfile.storybook для запуска стенда с документацией',
#   28800,
#   '',
#   '',
#   0],
#  4529373: ['Система.Вики',
#   1,
#   2,
#   'Средний',
#   "При вставке макроса 'Дерево страниц' возникает 403 ошибка на запрос /pages ",
#   0,
#   '',
#   '',
#   0],
#  4529671: ['Система.ХранениеАртефактов',
#   0,
#   1,
#   'Средний',
#   '[QA] ПЦК Активности',
#   86400,
#   '',
#   '',
#   0],
#  4529684: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   'КОПИЯ [QA] Автоматизация (рефакторинг+написание)',
#   14400,
#   '',
#   '',
#   0],
#  4530754: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Демо Стандартные решения',
#   14400,
#   '',
#   '',
#   0],
#  4530886: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[demo][june] Не происходит смена статуса согласований из Таск трекер.',
#   0,
#   '',
#   '',
#   0],
#  4531037: ['Система.Таск-трекер',
#   1,
#   2,
#   'Средний',
#   '[BE] API v1. Можно создать задачу, если у Таск трекер нет статусной модели',
#   0,
#   '',
#   '',
#   0],
#  4531407: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] Фрагмент LINK',
#   201600,
#   '',
#   '',
#   0],
#  4531412: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Юр.док.Доработка созданных шаблонов в json.Ч2',
#   14400,
#   '',
#   '',
#   0],
#  4531490: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[FE] Дашборд. Нотификации',
#   14400,
#   '',
#   '',
#   0],
#  4531552: ['Система.Таск-трекер',
#   0,
#   2,
#   'Высокий',
#   '[FE] Дашборд. Подключение к Канальному приложению',
#   57600,
#   '',
#   '',
#   0],
#  4531553: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Связаные фрагменты (POC)',
#   115200,
#   '',
#   '',
#   0],
#  4531616: ['Управление релизами изменениями',
#   0,
#   2,
#   'Средний',
#   '[DevOps][PPRC] Настроить TeamCity pipeline для развёртывания стенда с документацией (Storybook)',
#   0,
#   '',
#   '',
#   0],
#  4531653: ['Система.Таск-трекер',
#   0,
#   2,
#   'Критический',
#   '[FE] Дашборд. Удалить интеграции виджета Дашборда в Таск трекер',
#   28800,
#   '',
#   '',
#   0],
#  4531906: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Интеграционный плагин с Архитектурой',
#   57600,
#   '',
#   '',
#   0],
#  4531915: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Связаные фрагменты',
#   28800,
#   '',
#   '',
#   0],
#  4532022: ['Система. Движок',
#   0,
#   2,
#   'Средний',
#   '[UX] Статусные модели – подготовка исследования',
#   28800,
#   '',
#   '',
#   0],
#  4532093: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[FE] 3 типа списка в сравнениях табличного фрагмента + экран сравнения публикаций (доработка)',
#   28800,
#   '',
#   '',
#   0],
#  4532094: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Админка для конфигов',
#   129600,
#   '',
#   '',
#   0],
#  4532215: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Проработка ограничения количества контента во фрагменте',
#   72000,
#   '',
#   '',
#   0],
#  4532640: ['Система.Таск-трекер',
#   1,
#   2,
#   'Высокий',
#   '[FE] Создание Таск трекер из системного пространства. Избавиться от хардкода для пространства "Все"',
#   0,
#   '',
#   '',
#   0],
#  4532916: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BE] Переезд на контур Компания (Тестирование после переезда, Helm чарты)',
#   3600,
#   '',
#   '',
#   0],
#  4533016: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[QA] Дашборд. Geteway на GraalVM',
#   28800,
#   '',
#   '',
#   0],
#  4533463: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Критический',
#   '[QA] [тест-кейсы] Миграция статей стандартных решений',
#   57600,
#   '',
#   '',
#   0],
#  4533508: ['Система.ХранениеАртефактов',
#   0,
#   2,
#   'Средний',
#   '[BA] Ч2 Импорт данных из документа формата DOCX в часть существующего документа',
#   28800,
#   '',
#   '',
#   0],
#  4533564: ['Система.Таск-трекер',
#   0,
#   2,
#   'Средний',
#   '[BE] Добавление типов полей в таблицы - Поддержка экспорта',
#   0,
#   '',
#   '',
#   0],
#  ...}

# %%
sprints
# Out:
# {'Спринт 2024.3.1.NPP Shared Sprint': (0, 19907),
#  'Спринт 2024.3.2.NPP Shared Sprint': (1, 19921),
#  'Спринт 2024.3.3.NPP Shared Sprint': (2, 19935),
#  'Спринт 2024.3.4.NPP Shared Sprint': (3, 19949),
#  'Спринт 2024.3.5.NPP Shared Sprint': (4, 19963),
#  'Спринт 2024.3.6.NPP Shared Sprint': (5, 19977)}

# %%
h.filter(pl.col("entity_id")==3941779)
# Out:
# shape: (53, 7)
# ┌───────────┬───────────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────┐
# │ entity_id ┆ history_prope ┆ history_date  ┆ history_chang ┆ history_chang ┆ entity_id_pr ┆ day   │
# │ ---       ┆ rty_name      ┆ ---           ┆ e             ┆ e_prev        ┆ ev           ┆ ---   │
# │ i64       ┆ ---           ┆ datetime[ms]  ┆ ---           ┆ ---           ┆ ---          ┆ i64   │
# │           ┆ str           ┆               ┆ str           ┆ str           ┆ i64          ┆       │
# ╞═══════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════╡
# │ 3941779   ┆ Связанные     ┆ 2024-05-08    ┆ isClonedBy    ┆ Спринт        ┆ 2623949      ┆ 19851 │
# │           ┆ Задачи        ┆ 10:54:00      ┆               ┆ 2024.2.4.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-05-08    ┆ PPAR-6588     ┆ isClonedBy    ┆ 3941779      ┆ 19851 │
# │           ┆ Задачи        ┆ 10:54:00      ┆               ┆               ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-05-08    ┆ childdest     ┆ PPAR-6588     ┆ 3941779      ┆ 19851 │
# │           ┆ Задачи        ┆ 10:55:00      ┆               ┆               ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-05-08    ┆ PPAR-6588     ┆ childdest     ┆ 3941779      ┆ 19851 │
# │           ┆ Задачи        ┆ 10:55:00      ┆               ┆               ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-05-08    ┆ null          ┆ PPAR-6588     ┆ 3941779      ┆ 19851 │
# │           ┆ Задачи        ┆ 10:55:00      ┆               ┆               ┆              ┆       │
# │ …         ┆ …             ┆ …             ┆ …             ┆ …             ┆ …            ┆ …     │
# │ 3941779   ┆ Спринт        ┆ 2024-09-10    ┆ Спринт        ┆ Спринт        ┆ 2353124      ┆ 19976 │
# │           ┆               ┆ 13:18:00      ┆ 2024.3.6.NPP  ┆ 2024.3.6.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 3941779   ┆ Резолюция     ┆ 2024-09-19    ┆ Готово        ┆ closed        ┆ 2353124      ┆ 19985 │
# │           ┆               ┆ 15:48:00      ┆               ┆               ┆              ┆       │
# │ 3941779   ┆ Статус        ┆ 2024-09-19    ┆ closed        ┆ Готово        ┆ 3941779      ┆ 19985 │
# │           ┆               ┆ 15:48:00      ┆               ┆               ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-09-23    ┆ linksWithRequ ┆ PPIN-3519     ┆ 5129574      ┆ 19989 │
# │           ┆ Задачи        ┆ 09:14:00      ┆ est           ┆               ┆              ┆       │
# │ 3941779   ┆ Связанные     ┆ 2024-09-23    ┆ PROPRO-5677   ┆ linksWithRequ ┆ 3941779      ┆ 19989 │
# │           ┆ Задачи        ┆ 09:14:00      ┆               ┆ est           ┆              ┆       │
# └───────────┴───────────────┴───────────────┴───────────────┴───────────────┴──────────────┴───────┘

# %%
for (day,), df in history.group_by("day", maintain_order=True):
    df = df.with_columns(
        history_property_name=pl.when(pl.col("history_property_name")=="Статус").then(
            pl.col("history_change").replace_strict(
                ['created', 'closed', 'done', 'rejectedByThePerformer'],
            ['0', '2', '2', '2'], default='1', return_dtype=pl.String)
        ).otherwise(
            pl.col("history_property_name")
        )
    )
    df = df.group_by(["entity_id", "history_property_name"], maintain_order=True).last()
    for row in df.iter_rows():
        ent_id = row[0]
        if ent_id not in entities:
            continue
        ent = entities[ent_id]
        sprint_name = ent[7]
        sprint = sprints.get(sprint_name, None)
        day_offset = 15
        sprint_id = -1
        if sprint is not None:
            sprint_id = sprint[0]
            day_offset = sprint[1] - day
            if day_offset < 0:
                day_offset = 0
        # print(row)
        match row[1]:
            case "Резолюция":
                entities[ent_id][6] = row[3]
            case "0":
                print(row)
                ent[2] = 0
                if sprint_id!=-1 and day_offset < 14:
                    day_features[sprint_id, day_offset, Feature.to_do_estimation] += ent[5]
            case "1":
                ent[2] = 1
                if sprint_id!=-1 and day_offset < 14:
                    day_features[sprint_id, day_offset, Feature.processed_estimation] += ent[5]
            case "2":
                ent[2] = 2
                if sprint_id!=-1 and day_offset < 14:
                    if ent[6] in ['Отклонено', 'Дубликат', 'Отменен инициатором']:
                        day_features[sprint_id, day_offset, Feature.removed_estimation] += ent[5]
                    else:
                        day_features[sprint_id, day_offset, Feature.done_estimation] += ent[5]
            case "Спринт":
                new_sprint_name = row[3]
                
                old_sprint_name = ent[7]
                ent[7] = new_sprint_name                
                new_sprint = sprints.get(new_sprint_name, None)
                old_sprint = sprints.get(old_sprint_name, None)
                if new_sprint:
                    # print(ent[2])
                    day_offset = new_sprint[1] - day
                    sprint_id = new_sprint[0]
                    if day_offset < 0:
                        day_offset = 0
                    if day_offset < 14:
                        day_features[sprint_id, day_offset, Feature.created_tasks_estimation] += ent[5]
                        day_features[sprint_id, day_offset, Feature.created_tasks_amount] += 1
                        match ent[2]:
                            case 0:
                                day_features[sprint_id, day_offset, Feature.to_do_estimation] += ent[5]
                            case 1:
                                day_features[sprint_id, day_offset, Feature.processed_estimation] += ent[5]
                            case 2:
                                if ent[6] in ['Отклонено', 'Дубликат', 'Отменен инициатором']:
                                    day_features[sprint_id, day_offset, Feature.removed_estimation] += ent[5]
                                else:
                                    day_features[sprint_id, day_offset, Feature.done_estimation] += ent[5]
                            
                        day_features[sprint_id, day_offset, Feature.created_tasks_amount] += 1
                        
                        if ent[8]!=0:
                            blocked_by = entities.get(ent[8], None)
                            if blocked_by and blocked_by[2] !=2:
                                day_features[sprint_id, day_offset, Feature.blocked_tasks_estimation] += blocked_by[5]
                
                if old_sprint:
                    day_offset = old_sprint[1] - day
                    sprint_id = old_sprint[0]
                    if day_offset < 0:
                        day_offset = 0
                    if day_offset < 14:
                        # print(f"remove from {sprint_id} at day {day_offset}")
                        day_features[sprint_id, day_offset, Feature.excluded_tasks_estimation] += ent[5]
                        day_features[sprint_id, day_offset, Feature.excluded_tasks_amount] += 1
            case 'Связанные Задачи':
                if row[3]=="":
                    ent[8] = 0
                else:
                    if row[4]=="isBlockedBy":
                        blocked_by_id = ticket2id.get(row[3],0)
                        ent[8] = blocked_by_id
                        blocked_by = entities.get(blocked_by_id, None)
                        if blocked_by and blocked_by[3]!=2:
                            sprint_name = ent[7]
                            sprint = sprints.get(sprint_name, None)
                            if sprint is not None:
                                sprint_id = sprint[0]
                                day_offset = sprint[1] - day
                                if day_offset < 0:
                                    day_offset = 0
                                elif day_offset > 13:
                                    continue
                                day_features[sprint_id, day_offset, Feature.blocked_tasks_estimation] += blocked_by[5]
# Out:
# (102481, '0', datetime.datetime(2024, 2, 13, 15, 14), 'created', 'Спринт 2024.1.4.NPP Shared Sprint', 2623949, 19766)
# (3864586, '0', datetime.datetime(2024, 5, 20, 10, 12), 'created', 'inProgress', 3864586, 19863)
# (3907488, '0', datetime.datetime(2024, 5, 22, 8, 5), 'created', 'inProgress', 3907488, 19865)
# (4317978, '0', datetime.datetime(2024, 6, 21, 7, 30), 'created', 'inProgress', 4317978, 19895)
# (4317979, '0', datetime.datetime(2024, 6, 21, 7, 30), 'created', 'created', 4317978, 19895)
# (4319076, '0', datetime.datetime(2024, 7, 2, 17, 15), 'created', 'Спринт 2024.3.1.NPP Shared Sprint', 4334966, 19906)
# (4436271, '0', datetime.datetime(2024, 7, 3, 7, 40), 'created', 'Спринт 2024.3.1.NPP Shared Sprint', 4410789, 19907)
# (4436329, '0', datetime.datetime(2024, 7, 3, 8, 27), 'created', 'PPWI-5375', 4449638, 19907)
# (4448947, '0', datetime.datetime(2024, 7, 3, 9, 21), 'created', None, 4065300, 19907)
# (4364703, '0', datetime.datetime(2024, 7, 4, 7, 16), 'created', 'PPAR-7420', 4340645, 19908)
# (4461380, '0', datetime.datetime(2024, 7, 4, 8, 16), 'created', 'analysis', 4461380, 19908)
# (4328738, '0', datetime.datetime(2024, 7, 5, 6, 42), 'created', 'closed', 4219327, 19909)
# (4335505, '0', datetime.datetime(2024, 7, 7, 13, 31), 'created', 'inProgress', 4335505, 19911)
# (4335113, '0', datetime.datetime(2024, 7, 9, 13, 39), 'created', 'inProgress', 4335113, 19913)
# (4486289, '0', datetime.datetime(2024, 7, 12, 20, 46), 'created', 'Спринт 2024.3.3.NPP Shared Sprint', 4498685, 19916)
# (4486352, '0', datetime.datetime(2024, 7, 12, 20, 46), 'created', 'created', 4486289, 19916)
# (4531653, '0', datetime.datetime(2024, 7, 18, 7, 18), 'created', 'inProgress', 4411048, 19922)
# (4557011, '0', datetime.datetime(2024, 7, 21, 20, 41), 'created', 'inProgress', 4557011, 19925)
# (4557066, '0', datetime.datetime(2024, 7, 22, 7, 31), 'created', 'inProgress', 4557066, 19926)
# (4578093, '0', datetime.datetime(2024, 7, 24, 7, 54), 'created', 'inProgress', 4578093, 19928)
# (4364960, '0', datetime.datetime(2024, 7, 25, 7, 4), 'created', 'testing', 4579940, 19929)
# (4531552, '0', datetime.datetime(2024, 7, 29, 6, 43), 'created', 'PPFW-2784', 4609550, 19933)
# (4578082, '0', datetime.datetime(2024, 7, 31, 7, 11), 'created', 'Спринт 2024.3.3.NPP Shared Sprint', 4641958, 19935)
# (4647931, '0', datetime.datetime(2024, 8, 1, 7, 50), 'created', 'inProgress', 4647931, 19936)
# (4536933, '0', datetime.datetime(2024, 8, 1, 9, 11), 'created', 'Спринт 2024.3.3.NPP Shared Sprint', 4674630, 19936)
# (4634281, '0', datetime.datetime(2024, 8, 2, 6, 43), 'created', 'fixing', 3675079, 19937)
# (3902314, '0', datetime.datetime(2024, 8, 2, 7, 37), 'created', 'inProgress', 3902314, 19937)
# (4646403, '0', datetime.datetime(2024, 8, 2, 10, 53), 'created', 'inProgress', 4509564, 19937)
# (4509511, '0', datetime.datetime(2024, 8, 2, 11, 1), 'created', 'inProgress', 4509511, 19937)
# (4093732, '0', datetime.datetime(2024, 8, 7, 6, 53), 'created', 'analysis', 4596004, 19942)
# (4627018, '0', datetime.datetime(2024, 8, 14, 6, 54), 'created', 'Спринт 2024.3.4.NPP Shared Sprint', 4614947, 19949)
# (4707402, '0', datetime.datetime(2024, 8, 14, 11, 5), 'created', 'inProgress', 4707402, 19949)
# (4705044, '0', datetime.datetime(2024, 8, 14, 11, 5), 'created', 'inProgress', 4705044, 19949)
# (4092837, '0', datetime.datetime(2024, 8, 14, 13, 19), 'created', 'inProgress', 4092837, 19949)
# (4632599, '0', datetime.datetime(2024, 8, 14, 15, 2), 'created', 'inProgress', 4632599, 19949)
# (4092837, '0', datetime.datetime(2024, 8, 15, 11, 36), 'created', 'inProgress', 4403153, 19950)
# (4403153, '0', datetime.datetime(2024, 8, 15, 13, 20), 'created', 'inProgress', 4486669, 19950)
# (4642323, '0', datetime.datetime(2024, 8, 16, 8, 9), 'created', 'testing', 3675079, 19951)
# (4708677, '0', datetime.datetime(2024, 8, 16, 14, 5), 'created', 'inProgress', 4708677, 19951)
# (4075365, '0', datetime.datetime(2024, 8, 19, 9, 26), 'created', 'Спринт 2024.3.5.NPP Shared Sprint', 4056530, 19954)
# (4808612, '0', datetime.datetime(2024, 8, 22, 7, 45), 'created', 'closed', 4808579, 19957)
# (4673236, '0', datetime.datetime(2024, 8, 23, 6, 50), 'created', 'done', 4792425, 19958)
# (4697963, '0', datetime.datetime(2024, 8, 23, 6, 50), 'created', 'created', 4673236, 19958)
# (4733121, '0', datetime.datetime(2024, 8, 27, 8, 30), 'created', 'inProgress', 4733121, 19962)
# (4862921, '0', datetime.datetime(2024, 8, 28, 10, 4), 'created', 'inProgress', 4862921, 19963)
# (4857058, '0', datetime.datetime(2024, 9, 2, 7, 36), 'created', 'inProgress', 4838226, 19968)
# (4925615, '0', datetime.datetime(2024, 9, 3, 9, 55), 'created', 'inProgress', 4925896, 19969)
# (4925630, '0', datetime.datetime(2024, 9, 3, 9, 55), 'created', 'created', 4925630, 19969)
# (4925864, '0', datetime.datetime(2024, 9, 3, 9, 55), 'created', 'created', 4925630, 19969)
# (4925871, '0', datetime.datetime(2024, 9, 3, 9, 55), 'created', 'created', 4925864, 19969)
# (4925896, '0', datetime.datetime(2024, 9, 3, 9, 55), 'created', 'created', 4925871, 19969)
# (4955997, '0', datetime.datetime(2024, 9, 6, 13, 44), 'created', None, 3823975, 19972)
# (4707459, '0', datetime.datetime(2024, 9, 8, 11, 41), 'created', 'PPAR-8060', 4960288, 19974)
# (4867842, '0', datetime.datetime(2024, 9, 9, 6, 27), 'created', 'inProgress', 4867842, 19975)
# (4707516, '0', datetime.datetime(2024, 9, 9, 12, 52), 'created', 'Отменен инициатором', 4707516, 19975)
# (4838226, '0', datetime.datetime(2024, 9, 10, 14, 14), 'created', 'inProgress', 4994373, 19976)
# (4950588, '0', datetime.datetime(2024, 9, 11, 8, 2), 'created', 'inProgress', 4928635, 19977)
# (4456970, '0', datetime.datetime(2024, 9, 11, 15, 39), 'created', 'development', 4455271, 19977)
# (5042818, '0', datetime.datetime(2024, 9, 11, 17, 15), 'created', 'inProgress', 5042818, 19977)
# (5042891, '0', datetime.datetime(2024, 9, 11, 17, 22), 'created', 'inProgress', 5042891, 19977)
# (4857010, '0', datetime.datetime(2024, 9, 12, 6, 23), 'created', 'inProgress', 4679846, 19978)
# (4679846, '0', datetime.datetime(2024, 9, 12, 6, 26), 'created', 'created', 4857010, 19978)
# (4609089, '0', datetime.datetime(2024, 9, 13, 14, 38), 'created', 'Спринт 2024.3.6.NPP Shared Sprint', 5067719, 19979)
# (4928778, '0', datetime.datetime(2024, 9, 17, 7, 28), 'created', 'closed', 4740195, 19983)
# (4952630, '0', datetime.datetime(2024, 9, 17, 21, 18), 'created', 'PPRC-2505', 5101618, 19983)
# (5012668, '0', datetime.datetime(2024, 9, 18, 8, 19), 'created', 'inProgress', 5009753, 19984)
# (4747094, '0', datetime.datetime(2024, 9, 20, 7, 20), 'created', 'inProgress', 5131517, 19986)
# (5079192, '0', datetime.datetime(2024, 9, 21, 13, 55), 'created', 'inProgress', 5128489, 19987)
# (4952690, '0', datetime.datetime(2024, 9, 23, 6, 13), 'created', 'review', 5150670, 19989)
# (4951016, '0', datetime.datetime(2024, 9, 23, 11, 2), 'created', 'inProgress', 4952375, 19989)
# (4178222, '0', datetime.datetime(2024, 9, 23, 14, 43), 'created', 'inProgress', 4178222, 19989)
# (4216758, '0', datetime.datetime(2024, 9, 25, 12, 14), 'created', 'done', 5150670, 19991)
# (4950426, '0', datetime.datetime(2024, 10, 7, 17, 46), 'created', 'done', 4950562, 20003)
# (5179793, '0', datetime.datetime(2024, 10, 11, 7, 31), 'created', 'st', 4456502, 20007)
# (4679859, '0', datetime.datetime(2024, 10, 21, 7, 27), 'created', 'inProgress', 4679859, 20017)
# (4697963, '0', datetime.datetime(2024, 11, 6, 7, 8), 'created', 'Спринт 2024.4.4.NPP Shared Sprint', 4697963, 20033)

# %%
day_features[0]
# Out:
# array([[9.360000e+05, 1.857972e+07, 1.429572e+07, 1.872000e+05,
#         0.000000e+00, 8.020860e+06, 4.777380e+06, 4.240000e+02,
#         1.430000e+02],
#        [4.320000e+04, 1.580580e+06, 2.491200e+06, 1.440000e+04,
#         0.000000e+00, 4.071780e+06, 7.200000e+03, 2.600000e+02,
#         1.000000e+00],
#        [0.000000e+00, 5.760000e+04, 4.680000e+05, 0.000000e+00,
#         0.000000e+00, 5.256000e+05, 0.000000e+00, 2.200000e+01,
#         0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00],
#        [0.000000e+00, 1.446000e+04, 2.448000e+05, 0.000000e+00,
#         0.000000e+00, 2.304600e+05, 9.504000e+05, 2.000000e+01,
#         2.000000e+00],
#        [0.000000e+00, 1.440000e+05, 2.880000e+04, 0.000000e+00,
#         0.000000e+00, 1.728000e+05, 3.600000e+03, 4.000000e+00,
#         2.000000e+00],
#        [0.000000e+00, 0.000000e+00, 2.160000e+05, 0.000000e+00,
#         0.000000e+00, 2.160000e+05, 5.760000e+04, 1.200000e+01,
#         1.000000e+00],
#        [0.000000e+00, 0.000000e+00, 5.868000e+05, 0.000000e+00,
#         0.000000e+00, 5.868000e+05, 3.024000e+05, 3.200000e+01,
#         7.000000e+00],
#        [6.480000e+04, 9.504000e+05, 5.076000e+05, 0.000000e+00,
#         0.000000e+00, 1.522800e+06, 0.000000e+00, 3.400000e+01,
#         0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00],
#        [0.000000e+00, 0.000000e+00, 1.440000e+05, 0.000000e+00,
#         0.000000e+00, 1.440000e+05, 0.000000e+00, 8.000000e+00,
#         0.000000e+00],
#        [2.880000e+04, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 2.880000e+04, 0.000000e+00, 2.000000e+00,
#         0.000000e+00]])

# %%
Feature.blocked_tasks_estimation
# Out:
# <Feature.blocked_tasks_estimation: 4>

# %%
history = history.with_columns(pl.col("history_change").str.split(" -> ").list.last())
# history
history
# Out:
# shape: (28_756, 7)
# ┌───────────┬───────────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────┐
# │ entity_id ┆ history_prope ┆ history_date  ┆ history_chang ┆ history_chang ┆ entity_id_pr ┆ day   │
# │ ---       ┆ rty_name      ┆ ---           ┆ e             ┆ e_prev        ┆ ev           ┆ ---   │
# │ i64       ┆ ---           ┆ datetime[ms]  ┆ ---           ┆ ---           ┆ ---          ┆ i64   │
# │           ┆ str           ┆               ┆ str           ┆ str           ┆ i64          ┆       │
# ╞═══════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════╡
# │ 1805925   ┆ Спринт        ┆ 2023-07-12    ┆ Спринт        ┆ null          ┆ null         ┆ 19550 │
# │           ┆               ┆ 13:29:00      ┆ 2023.3.2.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1805925   ┆ Спринт        ┆ 2023-07-31    ┆ null          ┆ Спринт        ┆ 1805925      ┆ 19569 │
# │           ┆               ┆ 17:43:00      ┆               ┆ 2023.3.2.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 1805925   ┆ Спринт        ┆ 2023-07-31    ┆ Спринт        ┆ null          ┆ 1805925      ┆ 19569 │
# │           ┆               ┆ 17:43:00      ┆ 2023.3.3.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ 8             ┆ Спринт        ┆ 1805925      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆ 2023.3.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ PPTS-3254     ┆ 8             ┆ 1934905      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆               ┆              ┆       │
# │ …         ┆ …             ┆ …             ┆ …             ┆ …             ┆ …            ┆ …     │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.3.6.NPP  ┆ 2024.3.4.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.1.NPP  ┆ 2024.3.6.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.2.NPP  ┆ 2024.4.1.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.3.NPP  ┆ 2024.4.2.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.4.NPP  ┆ 2024.4.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# └───────────┴───────────────┴───────────────┴───────────────┴───────────────┴──────────────┴───────┘

# %%
history.filter(~pl.col("history_change").str.contains("->"))
# Out:
# shape: (26_299, 7)
# ┌───────────┬───────────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────┐
# │ entity_id ┆ history_prope ┆ history_date  ┆ history_chang ┆ history_chang ┆ entity_id_pr ┆ day   │
# │ ---       ┆ rty_name      ┆ ---           ┆ e             ┆ e_prev        ┆ ev           ┆ ---   │
# │ i64       ┆ ---           ┆ datetime[ms]  ┆ ---           ┆ ---           ┆ ---          ┆ i64   │
# │           ┆ str           ┆               ┆ str           ┆ str           ┆ i64          ┆       │
# ╞═══════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════╡
# │ 1805925   ┆ Спринт        ┆ 2023-07-12    ┆ Спринт        ┆ null          ┆ null         ┆ 19550 │
# │           ┆               ┆ 13:29:00      ┆ 2023.3.2.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1805925   ┆ Спринт        ┆ 2023-07-31    ┆ Спринт        ┆ null          ┆ 1805925      ┆ 19569 │
# │           ┆               ┆ 17:43:00      ┆ 2023.3.3.NPP  ┆               ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆               ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ 8             ┆ Спринт        ┆ 1805925      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆ 2023.3.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆               ┆ Shared Spr…   ┆              ┆       │
# │ 1934905   ┆ Связанные     ┆ 2023-08-04    ┆ PPTS-3254     ┆ 8             ┆ 1934905      ┆ 19573 │
# │           ┆ Задачи        ┆ 11:32:00      ┆               ┆               ┆              ┆       │
# │ 102481    ┆ Связанные     ┆ 2023-08-17    ┆ 29            ┆ PPTS-3254     ┆ 1934905      ┆ 19586 │
# │           ┆ Задачи        ┆ 14:11:00      ┆               ┆               ┆              ┆       │
# │ …         ┆ …             ┆ …             ┆ …             ┆ …             ┆ …            ┆ …     │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.3.6.NPP  ┆ 2024.3.4.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.1.NPP  ┆ 2024.3.6.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.2.NPP  ┆ 2024.4.1.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.3.NPP  ┆ 2024.4.2.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# │ 4707481   ┆ Спринт        ┆ 2024-11-06    ┆ Спринт        ┆ Спринт        ┆ 4707481      ┆ 20033 │
# │           ┆               ┆ 08:05:00      ┆ 2024.4.4.NPP  ┆ 2024.4.3.NPP  ┆              ┆       │
# │           ┆               ┆               ┆ Shared Spr…   ┆ Shared Spr…   ┆              ┆       │
# └───────────┴───────────────┴───────────────┴───────────────┴───────────────┴──────────────┴───────┘
